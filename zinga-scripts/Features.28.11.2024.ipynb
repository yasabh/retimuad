# %%
#!cp -r /content/drive/MyDrive/ICU_Dataset/ICUDatasetProcessed .

# %%
#!pip install numpy
#!pip install pandas
#!pip instal os
#!pip install scikit-learn

import numpy as np  
import pandas as pd
import os 
from sklearn.model_selection import train_test_split

# %%
df1 = pd.read_csv("ICUDatasetProcessed/environmentMonitoring.csv")
df1.columns
# Out:
# Index(['frame.time_delta', 'frame.time_relative', 'frame.len', 'ip.src',
#        'ip.dst', 'tcp.srcport', 'tcp.dstport', 'tcp.flags', 'tcp.time_delta',
#        'tcp.len', 'tcp.ack', 'tcp.connection.fin', 'tcp.connection.rst',
#        'tcp.connection.sack', 'tcp.connection.syn', 'tcp.flags.ack',
#        'tcp.flags.fin', 'tcp.flags.push', 'tcp.flags.reset', 'tcp.flags.syn',
#        'tcp.flags.urg', 'tcp.hdr_len', 'tcp.payload', 'tcp.pdu.size',
#        'tcp.window_size_value', 'tcp.checksum', 'mqtt.clientid',
#        'mqtt.clientid_len', 'mqtt.conack.flags', 'mqtt.conack.val',
#        'mqtt.conflag.passwd', 'mqtt.conflag.qos', 'mqtt.conflag.reserved',
#        'mqtt.conflag.retain', 'mqtt.conflag.willflag', 'mqtt.conflags',
#        'mqtt.dupflag', 'mqtt.hdrflags', 'mqtt.kalive', 'mqtt.len', 'mqtt.msg',
#        'mqtt.msgtype', 'mqtt.qos', 'mqtt.retain', 'mqtt.topic',
#        'mqtt.topic_len', 'mqtt.ver', 'mqtt.willmsg_len', 'ip.proto', 'ip.ttl',
#        'class', 'label'],
#       dtype='object')

# %%
df1
# Out:
#        frame.time_delta  frame.time_relative  frame.len        ip.src  \
# 0              0.000000             0.000000        105  10.5.126.151
# 1              0.000053             0.000053         72   10.5.126.84
# 2              0.000043             0.000096        105  10.5.126.153
# 3              0.000020             0.000116         72   10.5.126.84
# 4              0.000016             0.000132        105  10.5.126.155
# ...                 ...                  ...        ...           ...
# 31753          0.000008          2047.246123         80  10.5.150.152
# 31754          0.000058          2047.246181         72  10.5.150.109
# 31755          0.000011          2047.246192         72  10.5.150.109
# 31756          0.000010          2047.246202         72  10.5.150.109
# 31757          0.000008          2047.246210         72  10.5.150.109
#
#              ip.dst  tcp.srcport  tcp.dstport   tcp.flags  tcp.time_delta  \
# 0       10.5.126.84        40629         1883  0x00000018        0.000000
# 1      10.5.126.151         1883        40629  0x00000018        0.000053
# 2       10.5.126.84        45639         1883  0x00000018        0.000000
# 3      10.5.126.153         1883        45639  0x00000018        0.000020
# 4       10.5.126.84        45093         1883  0x00000018        0.000000
# ...             ...          ...          ...         ...             ...
# 31753  10.5.150.109        37239         1883  0x00000018        2.998972
# 31754  10.5.150.156         1883        44939  0x00000018        0.000083
# 31755  10.5.150.157         1883        44853  0x00000018        0.000119
# 31756  10.5.150.156         1883        37361  0x00000018        0.000109
# 31757  10.5.150.157         1883        34445  0x00000018        0.000095
#
#        tcp.len  ...  mqtt.qos  mqtt.retain  mqtt.topic  mqtt.topic_len  \
# 0           37  ...       0.0          0.0           0             0.0
# 1            4  ...       0.0          0.0           0             0.0
# 2           37  ...       0.0          0.0           0             0.0
# 3            4  ...       0.0          0.0           0             0.0
# 4           37  ...       0.0          0.0           0             0.0
# ...        ...  ...       ...          ...         ...             ...
# 31753       12  ...       0.0          0.0       CoGas             5.0
# 31754        4  ...       0.0          0.0           0             0.0
# 31755        4  ...       0.0          0.0           0             0.0
# 31756        4  ...       0.0          0.0           0             0.0
# 31757        4  ...       0.0          0.0           0             0.0
#
#        mqtt.ver  mqtt.willmsg_len  ip.proto  ip.ttl                  class  \
# 0           4.0               0.0         6      64  environmentMonitoring
# 1           0.0               0.0         6      64  environmentMonitoring
# 2           4.0               0.0         6      64  environmentMonitoring
# 3           0.0               0.0         6      64  environmentMonitoring
# 4           4.0               0.0         6      64  environmentMonitoring
# ...         ...               ...       ...     ...                    ...
# 31753       0.0               0.0         6      64  environmentMonitoring
# 31754       0.0               0.0         6      64  environmentMonitoring
# 31755       0.0               0.0         6      64  environmentMonitoring
# 31756       0.0               0.0         6      64  environmentMonitoring
# 31757       0.0               0.0         6      64  environmentMonitoring
#
#        label
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 31753      0
# 31754      0
# 31755      0
# 31756      0
# 31757      0
#
# [31758 rows x 52 columns]

# %%
import os
path = 'ICUDatasetProcessed/'
csvs = os.listdir(path)
csvs
# Out:
# ['AdaBoost_model.pkl',
#  'Attack.csv',
#  'Attack.zip',
#  'DecisionTree_model.pkl',
#  'ensemble_model.pkl',
#  'ensemble_model.zip',
#  'environmentMonitoring.csv',
#  'GaussianNB_model.pkl',
#  'KNN_model.pkl',
#  'LogisticRegression_model.pkl',
#  'patientMonitoring.csv',
#  'RandomForest_model.pkl']

# %%
import os
import pandas as pd

path = 'ICUDatasetProcessed/'
csvs = [file for file in os.listdir(path) if file.endswith('.csv')]

dfs = []

for csv in csvs:
    print(f'---- Reading {csv} ----')
    try:
        # reading the CSV
        df = pd.read_csv(os.path.join(path, csv))
        print(f'df.shape: {df.shape}')
        
        empty_cols = [col for col in df.columns if df[col].isnull().all()]
        print(f'empty_cols: {len(empty_cols)}')
        print(empty_cols)
        
        df.fillna(0, inplace=True)
        
        # Add the dataframe to the list
        dfs.append(df)
        print(f"Current dfs length: {len(dfs)}")
    except Exception as e:
        print(f"Error {csv}: {e}")

if dfs:
    common_columns = set.intersection(*(set(df.columns) for df in dfs))
    print(f"comon column for merge: {common_columns}")

    for col in common_columns:
        col_types = {df[col].dtype for df in dfs if col in df.columns}
        if len(col_types) > 1:
            print(f"Adjusting column '{col}' with different types: {col_types}")
            for df in dfs:
                if col in df.columns:
                    # Força todas as colunas para o tipo string como padrão
                    df[col] = df[col].astype(str)

    # Realizar o merge
    try:
        merged_df = dfs[0]
        for df in dfs[1:]:
            merged_df = pd.merge(merged_df, df, on=list(common_columns), how='outer')
        print(f"Final merged_df shape: {merged_df.shape}")
    except ValueError as e:
        print(f"Erro no merge: {e}. Realizando concatenação como fallback.")
        merged_df = pd.concat(dfs, ignore_index=True)

else:
    print("none of file was reading.")
# Out:
# ---- Reading Attack.csv ----
# C:\Users\ZINGA\AppData\Local\Temp\ipykernel_11836\3302865851.py:13: DtypeWarning: Columns (26,28,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(path, csv))
# df.shape: (80126, 52)
# empty_cols: 0
# []
# Current dfs length: 1
# ---- Reading environmentMonitoring.csv ----
# df.shape: (31758, 52)
# empty_cols: 0
# []
# Current dfs length: 2
# ---- Reading patientMonitoring.csv ----
# C:\Users\ZINGA\AppData\Local\Temp\ipykernel_11836\3302865851.py:13: DtypeWarning: Columns (26,28,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(path, csv))
# df.shape: (76810, 52)
# empty_cols: 0
# []
# Current dfs length: 3
# comon column for merge: {'mqtt.conack.val', 'mqtt.conflags', 'frame.time_delta', 'mqtt.conflag.retain', 'frame.time_relative', 'tcp.checksum', 'mqtt.ver', 'tcp.flags.fin', 'tcp.connection.fin', 'tcp.hdr_len', 'tcp.flags.reset', 'tcp.payload', 'mqtt.hdrflags', 'frame.len', 'mqtt.conflag.reserved', 'mqtt.len', 'tcp.ack', 'mqtt.msg', 'mqtt.conflag.passwd', 'mqtt.retain', 'mqtt.qos', 'tcp.srcport', 'mqtt.topic_len', 'ip.ttl', 'tcp.time_delta', 'mqtt.topic', 'ip.src', 'tcp.len', 'ip.dst', 'tcp.connection.sack', 'tcp.flags.syn', 'tcp.connection.syn', 'tcp.flags.urg', 'mqtt.conack.flags', 'class', 'mqtt.clientid_len', 'tcp.pdu.size', 'label', 'tcp.flags', 'tcp.connection.rst', 'tcp.flags.ack', 'mqtt.clientid', 'ip.proto', 'tcp.dstport', 'tcp.window_size_value', 'mqtt.conflag.qos', 'mqtt.conflag.willflag', 'mqtt.kalive', 'mqtt.willmsg_len', 'mqtt.dupflag', 'mqtt.msgtype', 'tcp.flags.push'}
# Adjusting column 'mqtt.len' with different types: {dtype('float64'), dtype('int64')}
# Adjusting column 'mqtt.msg' with different types: {dtype('float64'), dtype('O')}
# Adjusting column 'tcp.pdu.size' with different types: {dtype('float64'), dtype('int64')}
# Adjusting column 'mqtt.msgtype' with different types: {dtype('float64'), dtype('int64')}
# Final merged_df shape: (188694, 52)

# %%
df1
# Out:
#        frame.time_delta  frame.time_relative  frame.len        ip.src  \
# 0              0.000000             0.000000        105  10.5.126.151
# 1              0.000053             0.000053         72   10.5.126.84
# 2              0.000043             0.000096        105  10.5.126.153
# 3              0.000020             0.000116         72   10.5.126.84
# 4              0.000016             0.000132        105  10.5.126.155
# ...                 ...                  ...        ...           ...
# 31753          0.000008          2047.246123         80  10.5.150.152
# 31754          0.000058          2047.246181         72  10.5.150.109
# 31755          0.000011          2047.246192         72  10.5.150.109
# 31756          0.000010          2047.246202         72  10.5.150.109
# 31757          0.000008          2047.246210         72  10.5.150.109
#
#              ip.dst  tcp.srcport  tcp.dstport   tcp.flags  tcp.time_delta  \
# 0       10.5.126.84        40629         1883  0x00000018        0.000000
# 1      10.5.126.151         1883        40629  0x00000018        0.000053
# 2       10.5.126.84        45639         1883  0x00000018        0.000000
# 3      10.5.126.153         1883        45639  0x00000018        0.000020
# 4       10.5.126.84        45093         1883  0x00000018        0.000000
# ...             ...          ...          ...         ...             ...
# 31753  10.5.150.109        37239         1883  0x00000018        2.998972
# 31754  10.5.150.156         1883        44939  0x00000018        0.000083
# 31755  10.5.150.157         1883        44853  0x00000018        0.000119
# 31756  10.5.150.156         1883        37361  0x00000018        0.000109
# 31757  10.5.150.157         1883        34445  0x00000018        0.000095
#
#        tcp.len  ...  mqtt.qos  mqtt.retain  mqtt.topic  mqtt.topic_len  \
# 0           37  ...       0.0          0.0           0             0.0
# 1            4  ...       0.0          0.0           0             0.0
# 2           37  ...       0.0          0.0           0             0.0
# 3            4  ...       0.0          0.0           0             0.0
# 4           37  ...       0.0          0.0           0             0.0
# ...        ...  ...       ...          ...         ...             ...
# 31753       12  ...       0.0          0.0       CoGas             5.0
# 31754        4  ...       0.0          0.0           0             0.0
# 31755        4  ...       0.0          0.0           0             0.0
# 31756        4  ...       0.0          0.0           0             0.0
# 31757        4  ...       0.0          0.0           0             0.0
#
#        mqtt.ver  mqtt.willmsg_len  ip.proto  ip.ttl                  class  \
# 0           4.0               0.0         6      64  environmentMonitoring
# 1           0.0               0.0         6      64  environmentMonitoring
# 2           4.0               0.0         6      64  environmentMonitoring
# 3           0.0               0.0         6      64  environmentMonitoring
# 4           4.0               0.0         6      64  environmentMonitoring
# ...         ...               ...       ...     ...                    ...
# 31753       0.0               0.0         6      64  environmentMonitoring
# 31754       0.0               0.0         6      64  environmentMonitoring
# 31755       0.0               0.0         6      64  environmentMonitoring
# 31756       0.0               0.0         6      64  environmentMonitoring
# 31757       0.0               0.0         6      64  environmentMonitoring
#
#        label
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 31753      0
# 31754      0
# 31755      0
# 31756      0
# 31757      0
#
# [31758 rows x 52 columns]

# %%
import os
import pandas as pd

# path for the files 
path = 'ICUDatasetProcessed/'
csvs = [file for file in os.listdir(path) if file.endswith('.csv')]

#  DataFrames's list for storage
dfs = []
for csv in csvs:
    df = pd.read_csv(os.path.join(path, csv))
    dfs.append(df)

def find_inconsistent_columns(dfs):
    inconsistent_columns = {}
    for col in dfs[0].columns:  
        types = {df[col].dtype for df in dfs if col in df.columns}
        if len(types) > 1:
            inconsistent_columns[col] = list(types)
    return inconsistent_columns

# identify and correct
inconsistent_columns = find_inconsistent_columns(dfs)

if inconsistent_columns:
    print("Column with inconsistents types:")
    for col, types in inconsistent_columns.items():
        print(f"Colunm: {col}, finded types: {types}")
        
        
        for df in dfs:
            if col in df.columns:
                df[col] = df[col].astype(str)

    # reating merged_df after corrections 
    merged_df = pd.concat(dfs, ignore_index=True)
    print(f"After corrections, merged_df shape: {merged_df.shape}")
else:
    print("No columns with inconsistent types were found.")
# Out:
# C:\Users\ZINGA\AppData\Local\Temp\ipykernel_11836\602686355.py:11: DtypeWarning: Columns (26,28,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(path, csv))
# C:\Users\ZINGA\AppData\Local\Temp\ipykernel_11836\602686355.py:11: DtypeWarning: Columns (26,28,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(path, csv))
# Column with inconsistents types:
# Colunm: tcp.pdu.size, finded types: [dtype('float64'), dtype('int64')]
# Colunm: mqtt.len, finded types: [dtype('float64'), dtype('int64')]
# Colunm: mqtt.msg, finded types: [dtype('float64'), dtype('O')]
# Colunm: mqtt.msgtype, finded types: [dtype('float64'), dtype('int64')]
# After corrections, merged_df shape: (188694, 52)

# %%
total_rows = sum(len(df) for df in dfs)
print(f"Total rows in input DataFrames: {total_rows}")
print(f"Rows in merged_df: {len(merged_df)}")
# Out:
# Total rows in input DataFrames: 188694
# Rows in merged_df: 188694

# %%
for col in merged_df.select_dtypes(include='number').columns:
    print(f"{col} - Mean (merged): {merged_df[col].mean()}, Std (merged): {merged_df[col].std()}")
    for df in dfs:
        if col in df.columns:
            print(f"{col} - Mean (source): {df[col].mean()}, Std (source): {df[col].std()}")
# Out:
# frame.time_delta - Mean (merged): 0.07784608345787739, Std (merged): 0.4007755241267379
# frame.time_delta - Mean (source): 0.005482580660459402, Std (source): 0.21691897789986617
# frame.time_delta - Mean (source): 0.12532489703382346, Std (source): 0.5389979832019886
# frame.time_delta - Mean (source): 0.1337029492774276, Std (source): 0.4646222352208427
# frame.time_relative - Mean (merged): 1374.2475078541613, Std (merged): 1806.6347334060965
# frame.time_relative - Mean (source): 45.000738114344784, Std (source): 67.82898800653882
# frame.time_relative - Mean (source): 985.3084244355099, Std (source): 571.9079036945309
# frame.time_relative - Mean (source): 2921.691253243833, Std (source): 1891.5460985008262
# frame.len - Mean (merged): 164.8569429870584, Std (merged): 329.23818569340455
# frame.len - Mean (source): 281.17212889698726, Std (source): 481.186648922515
# frame.len - Mean (source): 78.29951508281378, Std (source): 5.168694392539927
# frame.len - Mean (source): 79.30844942064836, Std (source): 14.766325630188973
# tcp.srcport - Mean (merged): 35293.64402153752, Std (merged): 19335.803260919998
# tcp.srcport - Mean (source): 35633.73033721888, Std (source): 25332.316628749344
# tcp.srcport - Mean (source): 28729.786321556774, Std (source): 17608.643713029833
# tcp.srcport - Mean (source): 37652.780028642104, Std (source): 9866.519361605888
# tcp.dstport - Mean (merged): 12652.982241088746, Std (merged): 20280.18029391319
# tcp.dstport - Mean (source): 20841.75180340963, Std (source): 25344.442269125328
# tcp.dstport - Mean (source): 12681.55809559796, Std (source): 16895.4956909722
# tcp.dstport - Mean (source): 4098.87650045567, Std (source): 8897.447631463834
# tcp.time_delta - Mean (merged): 1.8704316241851855, Std (merged): 6.482881595853445
# tcp.time_delta - Mean (source): 0.015454988830091514, Std (source): 0.2518078814561068
# tcp.time_delta - Mean (source): 2.6050876247244115, Std (source): 1.967202501480919
# tcp.time_delta - Mean (source): 3.5017381287983493, Std (source): 9.752308562123389
# tcp.len - Mean (merged): 101.77400447285022, Std (merged): 331.69192020243923
# tcp.len - Mean (source): 224.75164116516487, Std (source): 482.27466107969263
# tcp.len - Mean (source): 10.299515082813778, Std (source): 5.168694392539927
# tcp.len - Mean (source): 11.308449420648353, Std (source): 14.766325630188973
# tcp.ack - Mean (merged): 66682.91788292155, Std (merged): 226307.57342934483
# tcp.ack - Mean (source): 155836.92334573047, Std (source): 326772.61216045154
# tcp.ack - Mean (source): 1483.7137099313559, Std (source): 2023.7312464340712
# tcp.ack - Mean (source): 637.3832443692228, Std (source): 3793.878932943004
# tcp.connection.fin - Mean (merged): 0.008749615780046, Std (merged): 0.09312951179746787
# tcp.connection.fin - Mean (source): 0.020605047050894842, Std (source): 0.14205889957823853
# tcp.connection.fin - Mean (source): 0.0, Std (source): 0.0
# tcp.connection.fin - Mean (source): 0.0, Std (source): 0.0
# tcp.connection.rst - Mean (merged): 0.008654223239742652, Std (merged): 0.09262490554385774
# tcp.connection.rst - Mean (source): 0.020380400868631906, Std (source): 0.14129858209737495
# tcp.connection.rst - Mean (source): 0.0, Std (source): 0.0
# tcp.connection.rst - Mean (source): 0.0, Std (source): 0.0
# tcp.connection.sack - Mean (merged): 0.010286495596044389, Std (merged): 0.10089964102076844
# tcp.connection.sack - Mean (source): 0.02422434665401992, Std (source): 0.15374596804892537
# tcp.connection.sack - Mean (source): 0.0, Std (source): 0.0
# tcp.connection.sack - Mean (source): 0.0, Std (source): 0.0
# tcp.connection.syn - Mean (merged): 0.010286495596044389, Std (merged): 0.10089964102076844
# tcp.connection.syn - Mean (source): 0.02422434665401992, Std (source): 0.15374596804892537
# tcp.connection.syn - Mean (source): 0.0, Std (source): 0.0
# tcp.connection.syn - Mean (source): 0.0, Std (source): 0.0
# tcp.flags.ack - Mean (merged): 0.9812765641726817, Std (merged): 0.135546914931026
# tcp.flags.ack - Mean (source): 0.9559069465591693, Std (source): 0.20530314687768267
# tcp.flags.ack - Mean (source): 1.0, Std (source): 0.0
# tcp.flags.ack - Mean (source): 1.0, Std (source): 0.0
# tcp.flags.fin - Mean (merged): 0.008749615780046, Std (merged): 0.09312951179746787
# tcp.flags.fin - Mean (source): 0.020605047050894842, Std (source): 0.14205889957823853
# tcp.flags.fin - Mean (source): 0.0, Std (source): 0.0
# tcp.flags.fin - Mean (source): 0.0, Std (source): 0.0
# tcp.flags.push - Mean (merged): 0.789373271010207, Std (merged): 0.4077548174529003
# tcp.flags.push - Mean (source): 0.5039812295634376, Std (source): 0.4999872695759899
# tcp.flags.push - Mean (source): 1.0, Std (source): 0.0
# tcp.flags.push - Mean (source): 1.0, Std (source): 0.0
# tcp.flags.reset - Mean (merged): 0.008654223239742652, Std (merged): 0.09262490554385774
# tcp.flags.reset - Mean (source): 0.020380400868631906, Std (source): 0.14129858209737495
# tcp.flags.reset - Mean (source): 0.0, Std (source): 0.0
# tcp.flags.reset - Mean (source): 0.0, Std (source): 0.0
# tcp.flags.syn - Mean (merged): 0.020572991192088778, Std (merged): 0.1419501673519869
# tcp.flags.syn - Mean (source): 0.04844869330803984, Std (source): 0.21471374616795383
# tcp.flags.syn - Mean (source): 0.0, Std (source): 0.0
# tcp.flags.syn - Mean (source): 0.0, Std (source): 0.0
# tcp.flags.urg - Mean (merged): 0.0, Std (merged): 0.0
# tcp.flags.urg - Mean (source): 0.0, Std (source): 0.0
# tcp.flags.urg - Mean (source): 0.0, Std (source): 0.0
# tcp.flags.urg - Mean (source): 0.0, Std (source): 0.0
# tcp.hdr_len - Mean (merged): 27.750855883069946, Std (merged): 6.005902295983866
# tcp.hdr_len - Mean (source): 21.99341037865362, Std (source): 5.228111366831688
# tcp.hdr_len - Mean (source): 32.0, Std (source): 0.0
# tcp.hdr_len - Mean (source): 32.0, Std (source): 0.0
# tcp.window_size_value - Mean (merged): 2338.45880102176, Std (merged): 7059.975270935903
# tcp.window_size_value - Mean (source): 4813.248246511744, Std (source): 10331.272125801459
# tcp.window_size_value - Mean (source): 512.0, Std (source): 0.0
# tcp.window_size_value - Mean (source): 512.0, Std (source): 0.0
# mqtt.clientid_len - Mean (merged): 0.2648202910532396, Std (merged): 10.129418286155579
# mqtt.clientid_len - Mean (source): 0.5886229189027282, Std (source): 15.512784798806903
# mqtt.clientid_len - Mean (source): 0.03041753259021349, Std (source): 0.835882781281124
# mqtt.clientid_len - Mean (source): 0.02395521416482229, Std (source): 0.7418916627670156
# mqtt.conack.val - Mean (merged): 0.0, Std (merged): 0.0
# mqtt.conack.val - Mean (source): 0.0, Std (source): 0.0
# mqtt.conack.val - Mean (source): 0.0, Std (source): 0.0
# mqtt.conack.val - Mean (source): 0.0, Std (source): 0.0
# mqtt.conflag.passwd - Mean (merged): 0.0, Std (merged): 0.0
# mqtt.conflag.passwd - Mean (source): 0.0, Std (source): 0.0
# mqtt.conflag.passwd - Mean (source): 0.0, Std (source): 0.0
# mqtt.conflag.passwd - Mean (source): 0.0, Std (source): 0.0
# mqtt.conflag.qos - Mean (merged): 0.0, Std (merged): 0.0
# mqtt.conflag.qos - Mean (source): 0.0, Std (source): 0.0
# mqtt.conflag.qos - Mean (source): 0.0, Std (source): 0.0
# mqtt.conflag.qos - Mean (source): 0.0, Std (source): 0.0
# mqtt.conflag.reserved - Mean (merged): 0.0, Std (merged): 0.0
# mqtt.conflag.reserved - Mean (source): 0.0, Std (source): 0.0
# mqtt.conflag.reserved - Mean (source): 0.0, Std (source): 0.0
# mqtt.conflag.reserved - Mean (source): 0.0, Std (source): 0.0
# mqtt.conflag.retain - Mean (merged): 0.0, Std (merged): 0.0
# mqtt.conflag.retain - Mean (source): 0.0, Std (source): 0.0
# mqtt.conflag.retain - Mean (source): 0.0, Std (source): 0.0
# mqtt.conflag.retain - Mean (source): 0.0, Std (source): 0.0
# mqtt.conflag.willflag - Mean (merged): 0.0, Std (merged): 0.0
# mqtt.conflag.willflag - Mean (source): 0.0, Std (source): 0.0
# mqtt.conflag.willflag - Mean (source): 0.0, Std (source): 0.0
# mqtt.conflag.willflag - Mean (source): 0.0, Std (source): 0.0
# mqtt.dupflag - Mean (merged): 0.030112245222423607, Std (merged): 0.1708966140323564
# mqtt.dupflag - Mean (source): 0.07091331153433343, Std (source): 0.2566815849539476
# mqtt.dupflag - Mean (source): 0.0, Std (source): 0.0
# mqtt.dupflag - Mean (source): 0.0, Std (source): 0.0
# mqtt.kalive - Mean (merged): 353.16957613914593, Std (merged): 4795.878011432041
# mqtt.kalive - Mean (source): 831.6109627336945, Std (source): 7332.653006094107
# mqtt.kalive - Mean (source): 0.07935008501794823, Std (source): 2.180563777255355
# mqtt.kalive - Mean (source): 0.06249186303866684, Std (source): 1.935369555038755
# mqtt.qos - Mean (merged): 0.17276648966050856, Std (merged): 0.378046276430035
# mqtt.qos - Mean (source): 0.30836432618625664, Std (source): 0.4618207772608671
# mqtt.qos - Mean (source): 0.2485043138736696, Std (source): 0.4321525198937259
# mqtt.qos - Mean (source): 0.0, Std (source): 0.0
# mqtt.retain - Mean (merged): 0.0006359502686889885, Std (merged): 0.025210101231241688
# mqtt.retain - Mean (source): 0.0014976412150862393, Std (source): 0.03867062126724116
# mqtt.retain - Mean (source): 0.0, Std (source): 0.0
# mqtt.retain - Mean (source): 0.0, Std (source): 0.0
# mqtt.topic_len - Mean (merged): 11.623342554612229, Std (merged): 21.127755775799226
# mqtt.topic_len - Mean (source): 20.28121957916282, Std (source): 29.996272733452656
# mqtt.topic_len - Mean (source): 4.4238302160085645, Std (source): 3.638250800661583
# mqtt.topic_len - Mean (source): 5.568415570889207, Std (source): 4.0275693538742505
# mqtt.ver - Mean (merged): 0.041824329337445815, Std (merged): 0.40687703322505403
# mqtt.ver - Mean (source): 0.09240446297082096, Std (source): 0.6009024659254422
# mqtt.ver - Mean (source): 0.005290005667863216, Std (source): 0.14537091848361677
# mqtt.ver - Mean (source): 0.004166124202577789, Std (source): 0.12902463700274683
# mqtt.willmsg_len - Mean (merged): 0.0, Std (merged): 0.0
# mqtt.willmsg_len - Mean (source): 0.0, Std (source): 0.0
# mqtt.willmsg_len - Mean (source): 0.0, Std (source): 0.0
# mqtt.willmsg_len - Mean (source): 0.0, Std (source): 0.0
# ip.proto - Mean (merged): 6.0, Std (merged): 0.0
# ip.proto - Mean (source): 6.0, Std (source): 0.0
# ip.proto - Mean (source): 6.0, Std (source): 0.0
# ip.proto - Mean (source): 6.0, Std (source): 0.0
# ip.ttl - Mean (merged): 72.38233330153582, Std (merged): 21.591857039952043
# ip.ttl - Mean (source): 83.7401093278087, Std (source): 29.558517974640715
# ip.ttl - Mean (source): 64.0, Std (source): 0.0
# ip.ttl - Mean (source): 64.0, Std (source): 0.0
# label - Mean (merged): 0.42463459357478245, Std (merged): 0.4942887317319277
# label - Mean (source): 1.0, Std (source): 0.0
# label - Mean (source): 0.0, Std (source): 0.0
# label - Mean (source): 0.0, Std (source): 0.0

# %%
print(merged_df.dtypes)
# Out:
# frame.time_delta         float64
# frame.time_relative      float64
# frame.len                  int64
# ip.src                    object
# ip.dst                    object
# tcp.srcport                int64
# tcp.dstport                int64
# tcp.flags                 object
# tcp.time_delta           float64
# tcp.len                    int64
# tcp.ack                    int64
# tcp.connection.fin       float64
# tcp.connection.rst       float64
# tcp.connection.sack      float64
# tcp.connection.syn       float64
# tcp.flags.ack              int64
# tcp.flags.fin              int64
# tcp.flags.push             int64
# tcp.flags.reset            int64
# tcp.flags.syn              int64
# tcp.flags.urg              int64
# tcp.hdr_len                int64
# tcp.payload               object
# tcp.pdu.size              object
# tcp.window_size_value      int64
# tcp.checksum              object
# mqtt.clientid             object
# mqtt.clientid_len        float64
# mqtt.conack.flags         object
# mqtt.conack.val          float64
# mqtt.conflag.passwd      float64
# mqtt.conflag.qos         float64
# mqtt.conflag.reserved    float64
# mqtt.conflag.retain      float64
# mqtt.conflag.willflag    float64
# mqtt.conflags             object
# mqtt.dupflag             float64
# mqtt.hdrflags             object
# mqtt.kalive              float64
# mqtt.len                  object
# mqtt.msg                  object
# mqtt.msgtype              object
# mqtt.qos                 float64
# mqtt.retain              float64
# mqtt.topic                object
# mqtt.topic_len           float64
# mqtt.ver                 float64
# mqtt.willmsg_len         float64
# ip.proto                   int64
# ip.ttl                     int64
# class                     object
# label                      int64
# dtype: object

# %%
valid_values = [0, 1]
invalid_rows = merged_df[~merged_df['label'].isin(valid_values)]
print(f"Invalid rows in 'label':\n{invalid_rows}")
# Out:
# Invalid rows in 'label':
# Empty DataFrame
# Columns: [frame.time_delta, frame.time_relative, frame.len, ip.src, ip.dst, tcp.srcport, tcp.dstport, tcp.flags, tcp.time_delta, tcp.len, tcp.ack, tcp.connection.fin, tcp.connection.rst, tcp.connection.sack, tcp.connection.syn, tcp.flags.ack, tcp.flags.fin, tcp.flags.push, tcp.flags.reset, tcp.flags.syn, tcp.flags.urg, tcp.hdr_len, tcp.payload, tcp.pdu.size, tcp.window_size_value, tcp.checksum, mqtt.clientid, mqtt.clientid_len, mqtt.conack.flags, mqtt.conack.val, mqtt.conflag.passwd, mqtt.conflag.qos, mqtt.conflag.reserved, mqtt.conflag.retain, mqtt.conflag.willflag, mqtt.conflags, mqtt.dupflag, mqtt.hdrflags, mqtt.kalive, mqtt.len, mqtt.msg, mqtt.msgtype, mqtt.qos, mqtt.retain, mqtt.topic, mqtt.topic_len, mqtt.ver, mqtt.willmsg_len, ip.proto, ip.ttl, class, label]
# Index: []
#
# [0 rows x 52 columns]

# %%
#!pip install matplotlib
import matplotlib.pyplot as plt

merged_df.hist(figsize=(15, 10), bins=20)
plt.tight_layout()
plt.show()

# %%
object_columns = merged_df.select_dtypes(include=['object']).columns
print(f"Object columns: {list(object_columns)}")
# Out:
# Object columns: ['ip.src', 'ip.dst', 'tcp.flags', 'tcp.payload', 'tcp.pdu.size', 'tcp.checksum', 'mqtt.clientid', 'mqtt.conack.flags', 'mqtt.conflags', 'mqtt.hdrflags', 'mqtt.len', 'mqtt.msg', 'mqtt.msgtype', 'mqtt.topic', 'class']

# %%
for col in object_columns:
    print(f"Column '{col}':")
    print(merged_df[col].value_counts())
    print("\n")
# Out:
# Column 'ip.src':
# ip.src
# 192.168.1.90    46210
# 192.168.1.91    24714
# 10.5.126.145    10596
# 10.5.126.147    10596
# 10.5.126.148    10518
# 10.5.126.146    10518
# 10.5.126.165     6858
# 10.5.126.167     6858
# 10.5.126.168     6782
# 10.5.126.166     6780
# 10.5.126.84      6084
# 10.16.120.44     5114
# 10.5.126.56      4544
# 10.16.120.72     4088
# 10.5.150.109     3222
# 10.5.150.157     1436
# 10.5.150.156     1436
# 10.5.150.152     1436
# 10.5.126.136     1356
# 10.5.126.132     1356
# 10.5.126.157     1356
# 10.5.126.152     1356
# 10.5.126.137     1356
# 10.5.126.156     1356
# 10.5.126.134      840
# 10.5.126.151      840
# 10.5.126.153      840
# 10.5.126.155      840
# 10.5.126.133      840
# 10.5.126.154      840
# 10.5.126.135      840
# 10.5.126.131      840
# 10.5.150.151      822
# 10.5.150.154      822
# 10.5.150.153      822
# 10.5.150.155      822
# 10.5.126.141      416
# 10.5.126.144      416
# 10.5.126.143      416
# 10.5.126.142      416
# 10.5.126.161      274
# 10.5.126.163      274
# 10.5.126.162      274
# 10.5.126.164      274
# Name: count, dtype: int64
#
#
# Column 'ip.dst':
# ip.dst
# 10.5.126.56     72266
# 192.168.1.91    46210
# 192.168.1.90    24714
# 10.5.126.84     14856
# 10.5.150.109     7596
# 10.16.120.72     5114
# 10.16.120.44     4088
# 10.5.150.157     1436
# 10.5.150.156     1436
# 10.5.126.157     1356
# 10.5.126.136     1356
# 10.5.126.137     1356
# 10.5.126.156     1356
# 10.5.126.148      344
# 10.5.126.146      344
# 10.5.126.145      344
# 10.5.126.144      344
# 10.5.126.147      344
# 10.5.126.142      344
# 10.5.126.141      344
# 10.5.126.143      344
# 10.5.126.162      224
# 10.5.126.165      224
# 10.5.126.167      224
# 10.5.126.164      224
# 10.5.126.166      224
# 10.5.126.163      224
# 10.5.126.161      224
# 10.5.126.168      224
# 10.5.150.153       70
# 10.5.150.154       70
# 10.5.150.151       70
# 10.5.150.155       70
# 10.5.150.152       70
# 10.5.126.151       66
# 10.5.126.155       66
# 10.5.126.134       66
# 10.5.126.132       66
# 10.5.126.153       66
# 10.5.126.133       66
# 10.5.126.135       66
# 10.5.126.154       66
# 10.5.126.131       66
# 10.5.126.152       66
# Name: count, dtype: int64
#
#
# Column 'tcp.flags':
# tcp.flags
# 0x00000018    148212
# 0x00000010     33316
# 0x00000012      1941
# 0x00000002      1941
# 0x00000004      1592
# 0x00000011       913
# 0x00000019       738
# 0x00000014        41
# Name: count, dtype: int64
#
#
# Column 'tcp.payload':
# tcp.payload
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 30:0a:00:07:41:69:72:46:6c:6f:77:30                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# d0:00                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# c0:00                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# 20:02:00:00                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 40:02:18:b7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 32:a0:01:00:41:6d:71:74:74:2d:6d:61:6c:61:72:69:61:2f:62:65:65:6d:2e:6c:6f:61:64:72:2d:4d:42:50:2d:64:69:2d:49:76:61:6e:2d:35:2e:6c:61:6e:2d:35:34:37:36:31:2d:30:2f:64:61:74:61:2f:36:33:33:33:2f:31:30:30:30:30:18:bd:66:38:35:39:34:31:63:32:66:63:45:39:39:34:63:32:30:46:62:62:38:33:63:61:44:38:44:62:64:42:30:37:35:37:62:66:43:39:45:63:44:63:46:43:31:41:34:31:38:46:39:33:33:39:39:41:45:30:33:64:34:30:30:44:33:45:30:46:66:66:43:37:42:46:41:30:38:65:62:45:45:34:30:65:64:37:41:34:61:64:43                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# 32:a9:01:00:41:6d:71:74:74:2d:6d:61:6c:61:72:69:61:2f:62:65:65:6d:2e:6c:6f:61:64:72:2d:4d:42:50:2d:64:69:2d:49:76:61:6e:2d:35:2e:6c:61:6e:2d:35:34:37:36:31:2d:30:2f:64:61:74:61:2f:36:33:33:34:2f:31:30:30:30:30:18:be:37:34:64:37:30:44:65:45:41:32:31:45:36:30:63:66:66:34:37:34:37:62:39:66:30:46:66:64:34:41:65:31:34:45:30:41:41:37:61:33:44:42:37:62:35:30:44:36:35:63:65:35:44:34:41:38:61:38:41:65:39:43:42:31:63:65:65:32:31:38:43:32:42:44:61:36:66:62:37:43:62:64:33:32:46:46:34:42:36:37:31:46:65:31:31:66:36:35:42:63:32:a7:01:00:41:6d:71:74:74:2d:6d:61:6c:61:72:69:61:2f:62:65:65:6d:2e:6c:6f:61:64:72:2d:4d:42:50:2d:64:69:2d:49:76:61:6e:2d:35:2e:6c:61:6e:2d:35:34:37:36:31:2d:30:2f:64:61:74:61:2f:36:33:33:35:2f:31:30:30:30:30:18:bf:63:62:45:45:63:39:33:44:30:37:33:35:37:34:62:35:44:36:38:64:46:43:63:43:63:39:45:35:62:63:37:32:42:30:37:41:39:31:41:38:35:42:62:34:41:39:39:63:34:45:31:65:46:36:44:30:34:30:41:45:32:61:41:32:37:39:62:46:34:64:30:43:32:66:65:35:31:33:32:44:62:37:63:41:66:62:35:64:65:34:46:45:62:66:31:65:32:32:32:a7:01:00:41:6d:71:74:74:2d:6d:61:6c:61:72:69:61:2f:62:65:65:6d:2e:6c:6f:61:64:72:2d:4d:42:50:2d:64:69:2d:49:76:61:6e:2d:35:2e:6c:61:6e:2d:35:34:37:36:31:2d:30:2f:64:61:74:61:2f:36:33:33:36:2f:31:30:30:30:30:18:c0:64:33:42:30:33:63:34:46:31:32:45:36:33:30:37:39:44:36:46:39:32:64:46:33:46:34:61:33:62:35:64:31:30:44:44:31:31:46:65:32:30:63:43:66:45:44:33:46:45:30:31:30:33:44:64:42:41:64:63:39:46:33:41:33:34:38:37:64:38:42:66:35:41:35:65:30:65:34:36:43:36:43:45:66:38:30:62:39:32:44:42:32:42:32:62:62:43:43:32:ae:01:00:41:6d:71:74:74:2d:6d:61:6c:61:72:69:61:2f:62:65:65:6d:2e:6c:6f:61:64:72:2d:4d:42:50:2d:64:69:2d:49:76:61:6e:2d:35:2e:6c:61:6e:2d:35:34:37:36:31:2d:30:2f:64:61:74:61:2f:36:33:33:37:2f:31:30:30:30:30:18:c1:66:31:64:38:66:33:64:30:44:31:43:38:42:63:44:38:31:45:34:42:35:32:65:44:44:35:39:30:30:65:31:35:43:31:38:45:63:41:32:34:38:64:41:63:37:41:44:35:44:62:64:63:62:61:42:63:31:61:36:46:45:46:43:62:34:41:30:66:33:41:31:44:66:64:35:33:39:39:38:65:41:38:61:33:32:36:43:37:32:42:33:62:46:38:43:37:34:65:62:31:63:44:64:44:63:32:ad:01:00:41:6d:71:74:74:2d:6d:61:6c:61:72:69:61:2f:62:65:65:6d:2e:6c:6f:61:64:72:2d:4d:42:50:2d:64:69:2d:49:76:61:6e:2d:35:2e:6c:61:6e:2d:35:34:37:36:31:2d:30:2f:64:61:74:61:2f:36:33:33:38:2f:31:30:30:30:30:18:c2:62:39:32:35:66:30:43:64:32:39:66:45:43:42:62:36:63:65:44:65:45:42:44:43:31:65:65:46:42:38:64:64:45:44:38:38:61:39:63:32:38:44:61:45:46:43:36:38:61:63:32:33:39:33:46:63:33:31:46:65:61:41:63:32:32:31:65:45:42:64:64:46:34:64:45:39:35:32:30:45:41:32:64:63:36:44:31:46:38:64:33:38:36:46:42:63:64:44:36:39:66:38:62:42:32:b0:01:00:41:6d:71:74:74:2d:6d:61:6c:61:72:69:61:2f:62:65:65:6d:2e:6c:6f:61:64:72:2d:4d:42:50:2d:64:69:2d:49:76:61:6e:2d:35:2e:6c:61:6e:2d:35:34:37:36:31:2d:30:2f:64:61:74:61:2f:36:33:33:39:2f:31:30:30:30:30:18:c3:46:63:65:43:38:38:34:44:63:42:34:34:64:44:32:44:35:39:66:38:46:66:63:45:62:36:34:43:46:63:35:30:30:39:42:45:31:35:31:62:32:63:64:41:66:66:66:33:36:36:46:33:65:37:34:44:31:34:33:31:65:33:38:46:42:46:62:66:65:41:35:64:38:34:32:36:31:43:31:45:31:65:66:39:31:39:46:31:33:32:65:32:31:37:62:37:41:66:43:30:39:32:30:31:63:65:33:32:a7:01:00:41:6d:71:74:74:2d:6d:61:6c:61:72:69:61:2f:62:65:65:6d:2e:6c:6f:61:64:72:2d:4d:42:50:2d:64:69:2d:49:76:61:6e:2d:35:2e:6c:61:6e:2d:35:34:37:36:31:2d:30:2f:64:61:74:61:2f:36:33:34:30:2f:31:30:30:30:30:18:c4:44:66:44:33:45:43:35:31:32:31:44:39:63:33:62:43:32:46:65:43:42:46:45:42:31:38:31:31:37:43:43:62:46:36:66:42:64:31:31:36:38:42:46:39:43:44:61:32:32:33:64:31:32:42:42:39:45:32:39:33:43:33:37:39:36:41:37:65:43:33:44:45:31:35:46:35:36:64:38:37:37:36:65:66:32:63:43:38:65:30:39:34:45:46:37:42:43:45:32:a3:01:00:41:6d:71:74:74:2d:6d:61:6c:61:72:69:61:2f:62:65:65:6d:2e:6c:6f:61:64:72:2d:4d:42:50:2d:64:69:2d:49:76:61:6e:2d:35:2e:6c:61:6e:2d:35:34:37:36:31:2d:30:2f:64:61:74:61:2f:36:33:34:31:2f:31:30:30:30:30:18:c5:46:61:38:36:66:33:35:38:42:39:46:41:46:36:37:42:65:35:30:41:66:36:35:65:44:66:61:66:46:62:35:33:34:64:45:63:46:63:62:32:64:62:61:61:33:31:30:6 ...
# 30:62:64:42:41:44:45:63:45:36:44:66:45:35:33:44:30:37:42:62:37:64:43:39:45:61:37:43:31:31:32:64:64:66:32:36:61:66:61:30:38:30:65:42:31:65:39:31:63:46:43:65:38:62:41:35:64:38:63:33:64:46:34:38:43:44:38:42:65:63:42:42:44:64:46:36:65:65:31:41:32:36:33:31:31:34:45:45:39:33:33:43:62:39:39:36:38:35:33:35                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 40:02:18:ae:40:02:18:af                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# Name: count, Length: 50526, dtype: int64
#
#
# Column 'tcp.pdu.size':
# tcp.pdu.size
# 0.0      31087
# 12       24622
# 4.0      20541
# 18       16913
# 10       16886
#          ...
# 153.0        1
# 34.0         1
# 47.0         1
# 56.0         1
# 16.0         1
# Name: count, Length: 93, dtype: int64
#
#
# Column 'tcp.checksum':
# tcp.checksum
# 0x0000110f    10750
# 0x00001119    10353
# 0x00001105    10256
# 0x00001104    10255
# 0x00001107    10214
#               ...
# 0x00006faf        1
# 0x0000bf61        1
# 0x000086f4        1
# 0x0000d8e9        1
# 0x0000d8f3        1
# Name: count, Length: 45930, dtype: int64
#
#
# Column 'mqtt.clientid':
# mqtt.clientid
# 0                     94183
# 0                     93194
# test                     41
# $                        41
# $topic                   41
#                       ...
# slowiteslowites364        1
# slowiteslowites394        1
# slowiteslowites379        1
# slowiteslowites393        1
# slowiteslowites380        1
# Name: count, Length: 1159, dtype: int64
#
#
# Column 'mqtt.conack.flags':
# mqtt.conack.flags
# 0             93527
# 0             93194
# 0x00000000     1973
# Name: count, dtype: int64
#
#
# Column 'mqtt.conflags':
# mqtt.conflags
# 0             93527
# 0             93194
# 0x00000002     1973
# Name: count, dtype: int64
#
#
# Column 'mqtt.hdrflags':
# mqtt.hdrflags
# 0x00000030    82517
# 0             31087
# 0x00000032    26918
# 0x00000040    26543
# 0x000000c0     5844
# 0x000000d0     5836
# 0x0000003a     5682
# 0x00000010     1973
# 0x00000020     1973
# 0x00000031      120
# 0x00000090       80
# 0x00000082       80
# 0x00000050       39
# 0x000000e0        2
# Name: count, dtype: int64
#
#
# Column 'mqtt.len':
# mqtt.len
# 0.0      31089
# 10       24622
# 2.0      20541
# 16       16913
# 7        16886
#          ...
# 150.0        1
# 32.0         1
# 45.0         1
# 54.0         1
# 14.0         1
# Name: count, Length: 92, dtype: int64
#
#
# Column 'mqtt.msg':
# mqtt.msg
# 0.0                                                                                                             53218
# 0                                                                                                               44451
# 59.0                                                                                                             2117
# 56.0                                                                                                             2113
# 53.0                                                                                                             2079
#                                                                                                                 ...
# dba2Db45fC84C8ce076aAB051Cc108dAE3eD82a78173CacfDBb94cAD231d0D53cD4D0870Caaf0C928de784b572cd31602DB3d1D9F6FE        1
# 5eBB6dcFBd9256F75a4B3bC6FaCd696EfDF94c84925BA8FaAdDdaF9cCFB5EBba3FefE8fbba90D94fd81a87A6668B                        1
# C1Ff79aed933133FbCcaeDAd78988Dd4bcfB596185bfA62aD2F1ECE8D864e4af3dE42D7E1b1fFe4fCCf81Df3f5e12EDDbAC3c               1
# BC0ee4feC7D1BbBcBBc999eA366ba21FDE0d8A72afB367fBB6CBf5e0A07c85Fc77b1faffDDAF85Ed61Afc9D3D                           1
# dFEe2F4F4eDDEA16F8FCFfBd6db7963FD7B8e3b031baA9DF6a2AcAAc2A2188D72dee06a763cf67de4f5c8cDE                            1
# Name: count, Length: 24713, dtype: int64
#
#
# Column 'mqtt.msgtype':
# mqtt.msgtype
# 3       88752
# 0.0     31087
# 3.0     26485
# 4.0     18651
# 4        7892
# 12       5844
# 13       5836
# 1.0      1851
# 2.0      1851
# 1         122
# 2         122
# 9.0        80
# 8.0        80
# 5.0        39
# 14.0        2
# Name: count, dtype: int64
#
#
# Column 'mqtt.topic':
# mqtt.topic
# 0                                                                    63591
# EMG                                                                  16886
# ECG                                                                  16886
# Pulsoximeter                                                         16884
# AirFlow                                                              16882
#                                                                      ...
# mqtt-malaria/beem.loadr-MBP-di-Ivan-5.lan-54761-5/data/2102/10000        1
# mqtt-malaria/beem.loadr-MBP-di-Ivan-5.lan-54761-5/data/2094/10000        1
# mqtt-malaria/beem.loadr-MBP-di-Ivan-5.lan-54761-5/data/2093/10000        1
# mqtt-malaria/beem.loadr-MBP-di-Ivan-5.lan-54761-5/data/2085/10000        1
# mqtt-malaria/beem.loadr-MBP-di-Ivan-5.lan-54761-5/data/2134/10000        1
# Name: count, Length: 23440, dtype: int64
#
#
# Column 'class':
# class
# Attack                   80126
# patientMonitoring        76810
# environmentMonitoring    31758
# Name: count, dtype: int64

# %%
merged_df['ip.src'] = merged_df['ip.src'].astype('category').cat.codes
merged_df['ip.dst'] = merged_df['ip.dst'].astype('category').cat.codes
merged_df['tcp.flags'] = merged_df['tcp.flags'].astype('category').cat.codes
merged_df.drop(columns=['tcp.payload'], inplace=True)
merged_df['mqtt.clientid'] = merged_df['mqtt.clientid'].astype('category').cat.codes
merged_df['mqtt.topic'] = merged_df['mqtt.topic'].astype('category').cat.codes
merged_df['mqtt.msgtype'] = merged_df['mqtt.msgtype'].astype('category').cat.codes
merged_df['mqtt.conflags'] = merged_df['mqtt.conflags'].astype('category').cat.codes
merged_df['class'] = merged_df['class'].astype('category').cat.codes

# %%
print(merged_df.dtypes)
# Out:
# frame.time_delta         float64
# frame.time_relative      float64
# frame.len                  int64
# ip.src                      int8
# ip.dst                      int8
# tcp.srcport                int64
# tcp.dstport                int64
# tcp.flags                   int8
# tcp.time_delta           float64
# tcp.len                    int64
# tcp.ack                    int64
# tcp.connection.fin       float64
# tcp.connection.rst       float64
# tcp.connection.sack      float64
# tcp.connection.syn       float64
# tcp.flags.ack              int64
# tcp.flags.fin              int64
# tcp.flags.push             int64
# tcp.flags.reset            int64
# tcp.flags.syn              int64
# tcp.flags.urg              int64
# tcp.hdr_len                int64
# tcp.pdu.size              object
# tcp.window_size_value      int64
# tcp.checksum              object
# mqtt.clientid              int16
# mqtt.clientid_len        float64
# mqtt.conack.flags         object
# mqtt.conack.val          float64
# mqtt.conflag.passwd      float64
# mqtt.conflag.qos         float64
# mqtt.conflag.reserved    float64
# mqtt.conflag.retain      float64
# mqtt.conflag.willflag    float64
# mqtt.conflags               int8
# mqtt.dupflag             float64
# mqtt.hdrflags             object
# mqtt.kalive              float64
# mqtt.len                  object
# mqtt.msg                  object
# mqtt.msgtype                int8
# mqtt.qos                 float64
# mqtt.retain              float64
# mqtt.topic                 int16
# mqtt.topic_len           float64
# mqtt.ver                 float64
# mqtt.willmsg_len         float64
# ip.proto                   int64
# ip.ttl                     int64
# class                       int8
# label                      int64
# dtype: object

# %%
object_columns = merged_df.select_dtypes(include=['object']).columns
print(f"Colunas com tipo 'object': {list(object_columns)}")
# Out:
# Colunas com tipo 'object': ['tcp.pdu.size', 'tcp.checksum', 'mqtt.conack.flags', 'mqtt.hdrflags', 'mqtt.len', 'mqtt.msg']

# %%
# Conversão para numérico, com fallback para NaN
merged_df['tcp.pdu.size'] = pd.to_numeric(merged_df['tcp.pdu.size'], errors='coerce')
merged_df['mqtt.len'] = pd.to_numeric(merged_df['mqtt.len'], errors='coerce')

# Conversão para categorias (codificação como números inteiros)
merged_df['tcp.checksum'] = merged_df['tcp.checksum'].astype('category').cat.codes
merged_df['mqtt.msg'] = merged_df['mqtt.msg'].astype('category').cat.codes
merged_df['mqtt.conack.flags'] = merged_df['mqtt.conack.flags'].astype('category').cat.codes
merged_df['mqtt.hdrflags'] = merged_df['mqtt.hdrflags'].astype('category').cat.codes

# %%
merged_df.drop(columns=['tcp.checksum', 'mqtt.msg'], inplace=True)

# %%
print(merged_df.dtypes)
# Out:
# frame.time_delta         float64
# frame.time_relative      float64
# frame.len                  int64
# ip.src                      int8
# ip.dst                      int8
# tcp.srcport                int64
# tcp.dstport                int64
# tcp.flags                   int8
# tcp.time_delta           float64
# tcp.len                    int64
# tcp.ack                    int64
# tcp.connection.fin       float64
# tcp.connection.rst       float64
# tcp.connection.sack      float64
# tcp.connection.syn       float64
# tcp.flags.ack              int64
# tcp.flags.fin              int64
# tcp.flags.push             int64
# tcp.flags.reset            int64
# tcp.flags.syn              int64
# tcp.flags.urg              int64
# tcp.hdr_len                int64
# tcp.pdu.size             float64
# tcp.window_size_value      int64
# mqtt.clientid              int16
# mqtt.clientid_len        float64
# mqtt.conack.flags           int8
# mqtt.conack.val          float64
# mqtt.conflag.passwd      float64
# mqtt.conflag.qos         float64
# mqtt.conflag.reserved    float64
# mqtt.conflag.retain      float64
# mqtt.conflag.willflag    float64
# mqtt.conflags               int8
# mqtt.dupflag             float64
# mqtt.hdrflags               int8
# mqtt.kalive              float64
# mqtt.len                 float64
# mqtt.msgtype                int8
# mqtt.qos                 float64
# mqtt.retain              float64
# mqtt.topic                 int16
# mqtt.topic_len           float64
# mqtt.ver                 float64
# mqtt.willmsg_len         float64
# ip.proto                   int64
# ip.ttl                     int64
# class                       int8
# label                      int64
# dtype: object

# %%
for col in merged_df.columns:
    unique_values = merged_df[col].nunique()
    print(f"Column '{col}': {unique_values} single values")
# Out:
# Coluna 'frame.time_delta': 11904 valores únicos
# Coluna 'frame.time_relative': 176587 valores únicos
# Coluna 'frame.len': 633 valores únicos
# Coluna 'ip.src': 44 valores únicos
# Coluna 'ip.dst': 44 valores únicos
# Coluna 'tcp.srcport': 2062 valores únicos
# Coluna 'tcp.dstport': 2062 valores únicos
# Coluna 'tcp.flags': 8 valores únicos
# Coluna 'tcp.time_delta': 49228 valores únicos
# Coluna 'tcp.len': 638 valores únicos
# Coluna 'tcp.ack': 26555 valores únicos
# Coluna 'tcp.connection.fin': 2 valores únicos
# Coluna 'tcp.connection.rst': 2 valores únicos
# Coluna 'tcp.connection.sack': 2 valores únicos
# Coluna 'tcp.connection.syn': 2 valores únicos
# Coluna 'tcp.flags.ack': 2 valores únicos
# Coluna 'tcp.flags.fin': 2 valores únicos
# Coluna 'tcp.flags.push': 2 valores únicos
# Coluna 'tcp.flags.reset': 2 valores únicos
# Coluna 'tcp.flags.syn': 2 valores únicos
# Coluna 'tcp.flags.urg': 1 valores únicos
# Coluna 'tcp.hdr_len': 4 valores únicos
# Coluna 'tcp.pdu.size': 84 valores únicos
# Coluna 'tcp.window_size_value': 57 valores únicos
# Coluna 'mqtt.clientid': 1159 valores únicos
# Coluna 'mqtt.clientid_len': 9 valores únicos
# Coluna 'mqtt.conack.flags': 3 valores únicos
# Coluna 'mqtt.conack.val': 1 valores únicos
# Coluna 'mqtt.conflag.passwd': 1 valores únicos
# Coluna 'mqtt.conflag.qos': 1 valores únicos
# Coluna 'mqtt.conflag.reserved': 1 valores únicos
# Coluna 'mqtt.conflag.retain': 1 valores únicos
# Coluna 'mqtt.conflag.willflag': 1 valores únicos
# Coluna 'mqtt.conflags': 3 valores únicos
# Coluna 'mqtt.dupflag': 2 valores únicos
# Coluna 'mqtt.hdrflags': 14 valores únicos
# Coluna 'mqtt.kalive': 7 valores únicos
# Coluna 'mqtt.len': 83 valores únicos
# Coluna 'mqtt.msgtype': 15 valores únicos
# Coluna 'mqtt.qos': 2 valores únicos
# Coluna 'mqtt.retain': 2 valores únicos
# Coluna 'mqtt.topic': 23440 valores únicos
# Coluna 'mqtt.topic_len': 37 valores únicos
# Coluna 'mqtt.ver': 2 valores únicos
# Coluna 'mqtt.willmsg_len': 1 valores únicos
# Coluna 'ip.proto': 1 valores únicos
# Coluna 'ip.ttl': 2 valores únicos
# Coluna 'class': 3 valores únicos
# Coluna 'label': 2 valores únicos

# %%
correlations = merged_df.corr()['label'].sort_values(ascending=False)
print("Correlation with the variable 'label':\n", correlations)
# Out:
# Correlation with the variable 'label':
#  label                    1.000000
# ip.ttl                   0.451898
# mqtt.topic_len           0.352042
# tcp.dstport              0.346884
# tcp.ack                  0.338438
# tcp.len                  0.318514
# mqtt.qos                 0.308138
# frame.len                0.303503
# tcp.window_size_value    0.301142
# mqtt.dupflag             0.205104
# tcp.flags.syn            0.168705
# tcp.connection.syn       0.118671
# tcp.connection.sack      0.118671
# tcp.flags.fin            0.109362
# tcp.connection.fin       0.109362
# tcp.flags.reset          0.108759
# tcp.connection.rst       0.108759
# mqtt.ver                 0.106796
# mqtt.kalive              0.085703
# mqtt.retain              0.029364
# mqtt.clientid_len        0.027462
# tcp.srcport              0.015110
# frame.time_delta        -0.155116
# tcp.flags.ack           -0.160791
# tcp.time_delta          -0.245814
# tcp.flags.push          -0.601284
# frame.time_relative     -0.632080
# tcp.hdr_len             -0.823547
# tcp.flags.urg                 NaN
# mqtt.conack.val               NaN
# mqtt.conflag.passwd           NaN
# mqtt.conflag.qos              NaN
# mqtt.conflag.reserved         NaN
# mqtt.conflag.retain           NaN
# mqtt.conflag.willflag         NaN
# mqtt.willmsg_len              NaN
# ip.proto                      NaN
# Name: label, dtype: float64

# %%
low_corr_cols = correlations[abs(correlations) < 0.1].index
print(f"Columns with low correlation:\n {list(low_corr_cols)}")
merged_df.drop(columns=low_corr_cols, inplace=True)
# Out:
# Columns with low correlation:
#  ['mqtt.kalive', 'mqtt.retain', 'mqtt.clientid_len', 'tcp.srcport']

# %%
nan_corr_cols = correlations[correlations.isna()].index
print(f"Columns with NaN in correlation\n {list(nan_corr_cols)}")
merged_df.drop(columns=nan_corr_cols, inplace=True)
# Out:
# Columns with NaN in correlation
#  ['tcp.flags.urg', 'mqtt.conack.val', 'mqtt.conflag.passwd', 'mqtt.conflag.qos', 'mqtt.conflag.reserved', 'mqtt.conflag.retain', 'mqtt.conflag.willflag', 'mqtt.willmsg_len', 'ip.proto']

# %%
print("DataFrame size after cleaning:", merged_df.shape)
print("Data types after cleaning:\n", merged_df.dtypes)
# Out:
# DataFrame size after cleaning: (188694, 39)
# Data types after cleaning:
#  frame.time_delta         float64
# frame.time_relative      float64
# frame.len                  int64
# ip.src                    object
# ip.dst                    object
# tcp.dstport                int64
# tcp.flags                 object
# tcp.time_delta           float64
# tcp.len                    int64
# tcp.ack                    int64
# tcp.connection.fin       float64
# tcp.connection.rst       float64
# tcp.connection.sack      float64
# tcp.connection.syn       float64
# tcp.flags.ack              int64
# tcp.flags.fin              int64
# tcp.flags.push             int64
# tcp.flags.reset            int64
# tcp.flags.syn              int64
# tcp.hdr_len                int64
# tcp.payload               object
# tcp.pdu.size              object
# tcp.window_size_value      int64
# tcp.checksum              object
# mqtt.clientid             object
# mqtt.conack.flags         object
# mqtt.conflags             object
# mqtt.dupflag             float64
# mqtt.hdrflags             object
# mqtt.len                  object
# mqtt.msg                  object
# mqtt.msgtype              object
# mqtt.qos                 float64
# mqtt.topic                object
# mqtt.topic_len           float64
# mqtt.ver                 float64
# ip.ttl                     int64
# class                     object
# label                      int64
# dtype: object

# %%
print("Remaining missing values ​​per column:\n", merged_df.isnull().sum())
# Out:
# Remaining missing values ​​per column:
#  frame.time_delta         0
# frame.time_relative      0
# frame.len                0
# ip.src                   0
# ip.dst                   0
# tcp.dstport              0
# tcp.flags                0
# tcp.time_delta           0
# tcp.len                  0
# tcp.ack                  0
# tcp.connection.fin       0
# tcp.connection.rst       0
# tcp.connection.sack      0
# tcp.connection.syn       0
# tcp.flags.ack            0
# tcp.flags.fin            0
# tcp.flags.push           0
# tcp.flags.reset          0
# tcp.flags.syn            0
# tcp.hdr_len              0
# tcp.payload              0
# tcp.pdu.size             0
# tcp.window_size_value    0
# tcp.checksum             0
# mqtt.clientid            0
# mqtt.conack.flags        0
# mqtt.conflags            0
# mqtt.dupflag             0
# mqtt.hdrflags            0
# mqtt.len                 0
# mqtt.msg                 0
# mqtt.msgtype             0
# mqtt.qos                 0
# mqtt.topic               0
# mqtt.topic_len           0
# mqtt.ver                 0
# ip.ttl                   0
# class                    0
# label                    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

merged_df.hist(figsize=(15, 10), bins=20)
plt.tight_layout()
plt.show()

# %%
# Set features to all columns except target variable 'label'
features = merged_df.drop(columns=['label'], axis=1)
# Check dimensions
print("Feature dimension:", features.shape)
print("dimension of merged_df:", merged_df.shape)
# Out:
# Feature dimension: (188694, 38)
# dimension of merged_df: (188694, 39)

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

scaler = MinMaxScaler()

features = merged_df.drop(columns=['label'])  #Remove target column
normalized_features = scaler.fit_transform(features)  # Normalize the data 

# Reconstructs the normalized DataFrame
df1_normalized = pd.DataFrame(normalized_features, columns=features.columns, index=merged_df.index)

# Adds 'label' column to normalized DataFrame
df1_normalized['label'] = merged_df['label'].values

print(df1_normalized.head())

# %%
print("Dimensão do DataFrame normalizado:", df1_normalized.shape)
print("Dimensão do DataFrame original:", merged_df.shape)
# Out:
# Dimensão do DataFrame normalizado: (188694, 35)
# Dimensão do DataFrame original: (188694, 35)

# %%
from sklearn.model_selection import train_test_split

# Verifica a consistência dos tamanhos
print(f"Dimensão de df1_normalized: {df1_normalized.shape}")
print(f"Dimensão de df1_normalized['label']: {df1_normalized['label'].shape}")

# Divide os dados para treino e teste
X_train, X_test, y_train, y_test = train_test_split(
    df1_normalized.drop(labels=['label'], axis=1),  # Todas as colunas exceto 'label'
    df1_normalized['label'],                       # A variável-alvo
    test_size=0.3,
    random_state=100
)

# Verifica as dimensões após a divisão
print(f"Dimensão de X_train: {X_train.shape}, y_train: {y_train.shape}")
print(f"Dimensão de X_test: {X_test.shape}, y_test: {y_test.shape}")
# Out:
# Dimensão de df1_normalized: (188694, 35)
# Dimensão de df1_normalized['label']: (188694,)
# Dimensão de X_train: (132085, 34), y_train: (132085,)
# Dimensão de X_test: (56609, 34), y_test: (56609,)

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression

print('---------- SelectFromModel LogisticRegression -----------')
embeded_LR_selector = SelectFromModel(LogisticRegression(penalty="l1", solver='liblinear'), threshold='0.9*median',
                                      max_features = 10)
embeded_LR_selector.fit(X_train, y_train)
embeded_LR_support = embeded_LR_selector.get_support()
print('embeded_LR_support',embeded_LR_support)
#embeded_lr_selector = embeded_lr_selector.scores_
#embeded_lr_support = embeded_lr_selector.get_support()
#embeded_LR_feature = df.loc[:,embeded_LR_support].columns.tolist()

embeded_LR_feature = X_train.loc[:,embeded_LR_support].columns.tolist()

print(len(embeded_LR_feature), 'selected features')
print('embeded_LR_features: ', embeded_LR_feature)
# Out:
# ---------- SelectFromModel LogisticRegression -----------
# embeded_LR_support [False False False  True  True False False False False False False False
#  False  True  True False  True False False False False False  True False
#  False False False  True False False  True False  True  True]
# 10 selected features
# embeded_LR_features:  ['ip.src', 'ip.dst', 'tcp.connection.syn', 'tcp.flags.ack', 'tcp.flags.push', 'mqtt.conack.flags', 'mqtt.msgtype', 'mqtt.topic_len', 'ip.ttl', 'class']

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn import linear_model #Linear Regression
#from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC   #SVM

from sklearn.metrics import confusion_matrix  
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.metrics import classification_report

# %%
print('--------Applying GaussianNB Classifier ----------')
gnb = GaussianNB()
gnb_fit = gnb.fit(X_train, y_train)  
gnb_prediction = gnb.predict(X_test) 

print('--------Applying KNeighborsClassifier Classifier ----------')
KNN_model = KNeighborsClassifier(n_neighbors=5)
KNN_model.fit(X_train, y_train)
KNN_prediction = KNN_model.predict(X_test)

print('--------Applying RandomForestClassifier Classifier ----------')
RF = RandomForestClassifier(max_depth=10, random_state=100)  
RF.fit(X_train, y_train)
RF_prediction = RF.predict(X_test)

print('--------Applying AdaBoostClassifier Classifier ----------')
AB = AdaBoostClassifier()
AB.fit(X_train, y_train)
AB_prediction = AB.predict(X_test)

print('--------Applying LogisticRegression Classifier ----------')
#LogR = LogisticRegression()
LogR = linear_model.LogisticRegression()
LogR.fit(X_train, y_train)
LogR_prediction = LogR.predict(X_test)

print('--------Applying DecisionTree Classifier ----------')
DT = DecisionTreeClassifier(criterion = "gini", random_state = 100, max_depth=10, min_samples_leaf=5)
DT.fit(X_train, y_train)
DT_prediction = DT.predict(X_test)
# Out:
# --------Applying GaussianNB Classifier ----------
# --------Applying KNeighborsClassifier Classifier ----------
# --------Applying RandomForestClassifier Classifier ----------
# --------Applying AdaBoostClassifier Classifier ----------
# /opt/conda/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# --------Applying LogisticRegression Classifier ----------
# --------Applying DecisionTree Classifier ----------

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

ensemble_model = VotingClassifier(
    estimators=[
        ('gnb', gnb),  # Gaussian Naive Bayes
        ('knn', KNN_model),  # K-Nearest Neighbors
        ('rf', RF),  # Random Forest
        ('ab', AB),  # AdaBoost
        ('logr', LogR),  # Logistic Regression
        ('dt', DT)  # Decision Tree
    ],
    voting='hard'  # 'hard' para votação majoritária; 'soft' se os modelos suportarem probabilidades
)

ensemble_model.fit(X_train, y_train)

ensemble_predictions = ensemble_model.predict(X_test)

print("Desempenho do Ensemble:")
print(f"Acurácia: {accuracy_score(y_test, ensemble_predictions)}")
print("\nMatriz de Confusão:")
print(confusion_matrix(y_test, ensemble_predictions))
print("\nRelatório de Classificação:")
print(classification_report(y_test, ensemble_predictions))
# Out:
# /opt/conda/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Desempenho do Ensemble:
# Acurácia: 1.0
#
# Matriz de Confusão:
# [[32620     0]
#  [    0 23989]]
#
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     32620
#            1       1.00      1.00      1.00     23989
#
#     accuracy                           1.00     56609
#    macro avg       1.00      1.00      1.00     56609
# weighted avg       1.00      1.00      1.00     56609

# %%
X_test.head()
# Out:
#         frame.time_delta  frame.time_relative  frame.len    ip.src    ip.dst  \
# 109898      1.350247e-07             0.253401   0.016939  0.860465  0.790698
# 135455      2.813015e-06             0.112392   0.014019  0.651163  0.744186
# 146863      6.593706e-06             0.301470   0.014019  0.651163  0.744186
# 12834       2.250412e-08             0.000737   0.067757  0.976744  1.000000
# 98063       3.825700e-07             0.250614   0.015187  0.418605  0.767442
#
#         tcp.dstport  tcp.flags  tcp.time_delta   tcp.len   tcp.ack  ...  \
# 109898          0.0   0.857143    8.324141e-02  0.008834  0.000034  ...
# 135455          0.0   0.857143    3.331109e-02  0.005889  0.000017  ...
# 146863          0.0   0.857143    3.332720e-02  0.005889  0.000041  ...
# 12834           0.0   0.857143    1.665630e-08  0.068316  0.001093  ...
# 98063           0.0   0.857143    4.991386e-02  0.007067  0.000034  ...
#
#         mqtt.dupflag  mqtt.hdrflags  mqtt.len  mqtt.msgtype  mqtt.qos  \
# 109898           0.0       0.230769  0.018786      0.571429       0.0
# 135455           0.0       0.230769  0.011561      0.571429       0.0
# 146863           0.0       0.230769  0.011561      0.571429       0.0
# 12834            0.0       0.384615  0.252890      0.642857       1.0
# 98063            0.0       0.230769  0.014451      0.571429       0.0
#
#         mqtt.topic  mqtt.topic_len  mqtt.ver  ip.ttl  class
# 109898    0.002517        0.121212       0.0     0.0    0.5
# 135455    0.002347        0.045455       0.0     0.0    1.0
# 146863    0.002347        0.045455       0.0     0.0    1.0
# 12834     0.279150        0.984848       0.0     0.0    0.0
# 98063     0.002304        0.075758       0.0     0.0    0.5
#
# [5 rows x 34 columns]

# %%
X_test.shape
# Out:
# (56609, 34)

# %%
X_test.head()
# Out:
#         frame.time_delta  frame.time_relative  frame.len    ip.src    ip.dst  \
# 109898      1.350247e-07             0.253401   0.016939  0.860465  0.790698
# 135455      2.813015e-06             0.112392   0.014019  0.651163  0.744186
# 146863      6.593706e-06             0.301470   0.014019  0.651163  0.744186
# 12834       2.250412e-08             0.000737   0.067757  0.976744  1.000000
# 98063       3.825700e-07             0.250614   0.015187  0.418605  0.767442
#
#         tcp.dstport  tcp.flags  tcp.time_delta   tcp.len   tcp.ack  ...  \
# 109898          0.0   0.857143    8.324141e-02  0.008834  0.000034  ...
# 135455          0.0   0.857143    3.331109e-02  0.005889  0.000017  ...
# 146863          0.0   0.857143    3.332720e-02  0.005889  0.000041  ...
# 12834           0.0   0.857143    1.665630e-08  0.068316  0.001093  ...
# 98063           0.0   0.857143    4.991386e-02  0.007067  0.000034  ...
#
#         mqtt.dupflag  mqtt.hdrflags  mqtt.len  mqtt.msgtype  mqtt.qos  \
# 109898           0.0       0.230769  0.018786      0.571429       0.0
# 135455           0.0       0.230769  0.011561      0.571429       0.0
# 146863           0.0       0.230769  0.011561      0.571429       0.0
# 12834            0.0       0.384615  0.252890      0.642857       1.0
# 98063            0.0       0.230769  0.014451      0.571429       0.0
#
#         mqtt.topic  mqtt.topic_len  mqtt.ver  ip.ttl  class
# 109898    0.002517        0.121212       0.0     0.0    0.5
# 135455    0.002347        0.045455       0.0     0.0    1.0
# 146863    0.002347        0.045455       0.0     0.0    1.0
# 12834     0.279150        0.984848       0.0     0.0    0.0
# 98063     0.002304        0.075758       0.0     0.0    0.5
#
# [5 rows x 34 columns]

# %%
print(X_test.columns.tolist())
# Out:
# ['frame.time_delta', 'frame.time_relative', 'frame.len', 'ip.src', 'ip.dst', 'tcp.dstport', 'tcp.flags', 'tcp.time_delta', 'tcp.len', 'tcp.ack', 'tcp.connection.fin', 'tcp.connection.rst', 'tcp.connection.sack', 'tcp.connection.syn', 'tcp.flags.ack', 'tcp.flags.fin', 'tcp.flags.push', 'tcp.flags.reset', 'tcp.flags.syn', 'tcp.hdr_len', 'tcp.pdu.size', 'tcp.window_size_value', 'mqtt.conack.flags', 'mqtt.conflags', 'mqtt.dupflag', 'mqtt.hdrflags', 'mqtt.len', 'mqtt.msgtype', 'mqtt.qos', 'mqtt.topic', 'mqtt.topic_len', 'mqtt.ver', 'ip.ttl', 'class']

# %%
#!pip install confluent-kafka
# Out:
# Requirement already satisfied: confluent-kafka in /opt/conda/lib/python3.11/site-packages (2.6.1)

# %%
#!pip install confluent-kafka
# Instalar dependência do Kafka (se necessário)
# !pip install confluent-kafka

from confluent_kafka import Producer
import pandas as pd
import joblib
import time
import json

producer_conf = {
    'bootstrap.servers': 'kafka:9092'
}
producer = Producer(producer_conf)

def delivery_report(err, msg):
    if err is not None:
        print(f"Erro ao enviar mensagem: {err}")
    else:
        print(f"Mensagem enviada com sucesso para {msg.topic()} [{msg.partition()}]")

ensemble_model = joblib.load('ensemble_model.pkl')
print("Modelo ensemble carregado com sucesso.")

X_data = X_test.copy() 


for index, row in X_data.iterrows():
    X_row = pd.DataFrame([row], columns=X_data.columns)

    expected_features = ensemble_model.feature_names_in_

    for col in expected_features:
        if col not in X_row.columns:
            X_row[col] = 0  # Ou outro valor padrão adequado

    X_row = X_row[expected_features]

    prediction = ensemble_model.predict(X_row)[0]
    label_type = 0 if prediction == 0 else 1

    # Criar o payload
    payload = {
        "frame.time_delta": row.get("frame.time_delta", None),
        "frame.time_relative": row.get("frame.time_relative", None),
        "frame.len": row.get("frame.len", None),
        "ip.src": row.get("ip.src", None),
        "ip.dst": row.get("ip.dst", None),
        "tcp.dstport": row.get("tcp.dstport", None),
        "tcp.flags": row.get("tcp.flags", None),
        "tcp.time_delta": row.get("tcp.time_delta", None),
        "tcp.len": row.get("tcp.len", None),
        "tcp.ack": row.get("tcp.ack", None),
        "tcp.connection.fin": row.get("tcp.connection.fin", None),
        "tcp.connection.rst": row.get("tcp.connection.rst", None),
        "tcp.connection.sack": row.get("tcp.connection.sack", None),
        "tcp.connection.syn": row.get("tcp.connection.syn", None),
        "tcp.flags.ack": row.get("tcp.flags.ack", None),
        "tcp.flags.fin": row.get("tcp.flags.fin", None),
        "tcp.flags.push": row.get("tcp.flags.push", None),
        "tcp.flags.reset": row.get("tcp.flags.reset", None),
        "tcp.flags.syn": row.get("tcp.flags.syn", None),
        "tcp.hdr_len": row.get("tcp.hdr_len", None),
        "tcp.pdu.size": row.get("tcp.pdu.size", None),
        "tcp.window_size_value": row.get("tcp.window_size_value", None),
        "mqtt.conack.flags": row.get("mqtt.conack.flags", None),
        "mqtt.conflags": row.get("mqtt.conflags", None),
        "mqtt.dupflag": row.get("mqtt.dupflag", None),
        "mqtt.hdrflags": row.get("mqtt.hdrflags", None),
        "mqtt.len": row.get("mqtt.len", None),
        "mqtt.msgtype": row.get("mqtt.msgtype", None),
        "mqtt.qos": row.get("mqtt.qos", None),
        "mqtt.topic": row.get("mqtt.topic", None),
        "mqtt.topic_len": row.get("mqtt.topic_len", None),
        "mqtt.ver": row.get("mqtt.ver", None),
        "ip.ttl": row.get("ip.ttl", None),
        "class": row.get("class", None),
        "label": label_type
    }

    producer.produce(
        topic='kf-topic',
        value=json.dumps(payload),
        callback=delivery_report
    )

    producer.flush()
    print(f"Publicado no Kafka: {payload}")

    time.sleep(10)
# Out:
# Modelo ensemble carregado com sucesso.
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(1.3502470378224225e-07), 'frame.time_relative': np.float64(0.2534013693884243), 'frame.len': np.float64(0.0169392523364486), 'ip.src': np.float64(0.8604651162790697), 'ip.dst': np.float64(0.7906976744186046), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.08324141274241918), 'tcp.len': np.float64(0.008833922261484098), 'tcp.ack': np.float64(3.444438865880556e-05), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.02158273381294964), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.23076923076923078), 'mqtt.len': np.float64(0.018786127167630055), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0025171722343103374), 'mqtt.topic_len': np.float64(0.12121212121212122), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.5), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(2.813014662130047e-06), 'frame.time_relative': np.float64(0.11239233947419815), 'frame.len': np.float64(0.014018691588785048), 'ip.src': np.float64(0.6511627906976745), 'ip.dst': np.float64(0.7441860465116279), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.033311092725512366), 'tcp.len': np.float64(0.005889281507656065), 'tcp.ack': np.float64(1.6930292730599342e-05), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.014388489208633094), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.23076923076923078), 'mqtt.len': np.float64(0.011560693641618497), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.002346516489611332), 'mqtt.topic_len': np.float64(0.045454545454545456), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(1.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(6.5937063680328305e-06), 'frame.time_relative': np.float64(0.3014698455958645), 'frame.len': np.float64(0.014018691588785048), 'ip.src': np.float64(0.6511627906976745), 'ip.dst': np.float64(0.7441860465116279), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.03332719937169755), 'tcp.len': np.float64(0.005889281507656065), 'tcp.ack': np.float64(4.1450027030088045e-05), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.014388489208633094), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.0), 'mqtt.conflags': np.float64(0.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.23076923076923078), 'mqtt.len': np.float64(0.011560693641618497), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.002346516489611332), 'mqtt.topic_len': np.float64(0.045454545454545456), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(1.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(2.2504117297040374e-08), 'frame.time_relative': np.float64(0.0007370583626570634), 'frame.len': np.float64(0.0677570093457944), 'ip.src': np.float64(0.9767441860465116), 'ip.dst': np.float64(1.0), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(1.66563042245984e-08), 'tcp.len': np.float64(0.06831566548881036), 'tcp.ack': np.float64(0.0010934633891176747), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.0), 'tcp.pdu.size': np.float64(0.2561151079136691), 'tcp.window_size_value': np.float64(0.06250095368886854), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.38461538461538464), 'mqtt.len': np.float64(0.2528901734104046), 'mqtt.msgtype': np.float64(0.6428571428571428), 'mqtt.qos': np.float64(1.0), 'mqtt.topic': np.float64(0.27915013439139896), 'mqtt.topic_len': np.float64(0.9848484848484849), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(3.8256999404968637e-07), 'frame.time_relative': np.float64(0.2506143206058964), 'frame.len': np.float64(0.015186915887850469), 'ip.src': np.float64(0.41860465116279066), 'ip.dst': np.float64(0.7674418604651163), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.049913863588332906), 'tcp.len': np.float64(0.007067137809187279), 'tcp.ack': np.float64(3.444438865880556e-05), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.017266187050359712), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.23076923076923078), 'mqtt.len': np.float64(0.014450867052023121), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0023038525534365803), 'mqtt.topic_len': np.float64(0.07575757575757576), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.5), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(1.1702140994460995e-06), 'frame.time_relative': np.float64(0.1648485253075406), 'frame.len': np.float64(0.015186915887850469), 'ip.src': np.float64(0.5116279069767442), 'ip.dst': np.float64(0.7674418604651163), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.0499796060211074), 'tcp.len': np.float64(0.007067137809187279), 'tcp.ack': np.float64(0.0008716181740270627), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.017266187050359712), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.38461538461538464), 'mqtt.len': np.float64(0.014450867052023121), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(1.0), 'mqtt.topic': np.float64(0.002645164042834592), 'mqtt.topic_len': np.float64(0.07575757575757576), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.5), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(5.355979916693359e-06), 'frame.time_relative': np.float64(0.007054033043607523), 'frame.len': np.float64(0.003504672897196262), 'ip.src': np.float64(1.0), 'ip.dst': np.float64(0.9767441860465116), 'tcp.dstport': np.float64(0.8285840095615525), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(3.964200405452754e-06), 'tcp.len': np.float64(0.002355712603062426), 'tcp.ack': np.float64(0.5376231970697749), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.0), 'tcp.pdu.size': np.float64(0.0057553956834532375), 'tcp.window_size_value': np.float64(0.06257724879835203), 'mqtt.conack.flags': np.float64(0.0), 'mqtt.conflags': np.float64(0.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.5384615384615385), 'mqtt.len': np.float64(0.002890173410404624), 'mqtt.msgtype': np.float64(0.7857142857142857), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0020905328725628228), 'mqtt.topic_len': np.float64(0.0), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(1.0), 'class': np.float64(0.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(0.0224659278099873), 'frame.time_relative': np.float64(0.8227202771460852), 'frame.len': np.float64(0.014018691588785048), 'ip.src': np.float64(0.3023255813953488), 'ip.dst': np.float64(0.7441860465116279), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.03317169611545671), 'tcp.len': np.float64(0.005889281507656065), 'tcp.ack': np.float64(0.00010800359155727166), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.014388489208633094), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.0), 'mqtt.conflags': np.float64(0.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.23076923076923078), 'mqtt.len': np.float64(0.011560693641618497), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.002346516489611332), 'mqtt.topic_len': np.float64(0.045454545454545456), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(1.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(6.751235189112112e-08), 'frame.time_relative': np.float64(0.0036773724822633047), 'frame.len': np.float64(0.0), 'ip.src': np.float64(0.9767441860465116), 'ip.dst': np.float64(1.0), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.2857142857142857), 'tcp.time_delta': np.float64(4.996891267379521e-08), 'tcp.len': np.float64(0.0), 'tcp.ack': np.float64(0.009313412411422459), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(0.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.0), 'tcp.pdu.size': np.float64(0.0), 'tcp.window_size_value': np.float64(0.06247043564507515), 'mqtt.conack.flags': np.float64(0.0), 'mqtt.conflags': np.float64(0.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.0), 'mqtt.len': np.float64(0.0), 'mqtt.msgtype': np.float64(0.0), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0020905328725628228), 'mqtt.topic_len': np.float64(0.0), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(3.060559952397491e-06), 'frame.time_relative': np.float64(0.7909554900936034), 'frame.len': np.float64(0.014018691588785048), 'ip.src': np.float64(0.3023255813953488), 'ip.dst': np.float64(0.7441860465116279), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.0333003494092875), 'tcp.len': np.float64(0.005889281507656065), 'tcp.ack': np.float64(0.00010450077237163043), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.014388489208633094), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.0), 'mqtt.conflags': np.float64(0.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.23076923076923078), 'mqtt.len': np.float64(0.011560693641618497), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.002346516489611332), 'mqtt.topic_len': np.float64(0.045454545454545456), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(1.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(9.00164691881615e-08), 'frame.time_relative': np.float64(0.00010134141998814996), 'frame.len': np.float64(0.007009345794392524), 'ip.src': np.float64(0.0), 'ip.dst': np.float64(0.023255813953488372), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.2857142857142857), 'tcp.time_delta': np.float64(4.313982794170986e-06), 'tcp.len': np.float64(0.0), 'tcp.ack': np.float64(2.9190159880343695e-06), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(0.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.0), 'tcp.window_size_value': np.float64(0.0034943160143434807), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.0), 'mqtt.len': np.float64(0.0), 'mqtt.msgtype': np.float64(0.0), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0021331968087375743), 'mqtt.topic_len': np.float64(0.0), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(2.768006427535966e-06), 'frame.time_relative': np.float64(0.11238172692020132), 'frame.len': np.float64(0.01869158878504673), 'ip.src': np.float64(0.37209302325581395), 'ip.dst': np.float64(0.7441860465116279), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.033288440151766914), 'tcp.len': np.float64(0.010600706713780918), 'tcp.ack': np.float64(1.6930292730599342e-05), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.025899280575539568), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.23076923076923078), 'mqtt.len': np.float64(0.023121387283236993), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0026025001066598405), 'mqtt.topic_len': np.float64(0.18181818181818182), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(1.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(0.0), 'frame.time_relative': np.float64(0.006179841757054421), 'frame.len': np.float64(0.0), 'ip.src': np.float64(0.9767441860465116), 'ip.dst': np.float64(1.0), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.2857142857142857), 'tcp.time_delta': np.float64(0.0), 'tcp.len': np.float64(0.0), 'tcp.ack': np.float64(0.005345885880486144), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(0.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.0), 'tcp.pdu.size': np.float64(0.0), 'tcp.window_size_value': np.float64(0.06247043564507515), 'mqtt.conack.flags': np.float64(0.0), 'mqtt.conflags': np.float64(0.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.0), 'mqtt.len': np.float64(0.0), 'mqtt.msgtype': np.float64(0.0), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0020905328725628228), 'mqtt.topic_len': np.float64(0.0), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(7.426358708023325e-07), 'frame.time_relative': np.float64(0.5564977638946371), 'frame.len': np.float64(0.013434579439252338), 'ip.src': np.float64(0.3488372093023256), 'ip.dst': np.float64(0.7441860465116279), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.03330642896032948), 'tcp.len': np.float64(0.005300353356890459), 'tcp.ack': np.float64(7.414300609607299e-05), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.012949640287769784), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.0), 'mqtt.conflags': np.float64(0.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.23076923076923078), 'mqtt.len': np.float64(0.010115606936416185), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.002389180425786083), 'mqtt.topic_len': np.float64(0.045454545454545456), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(1.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(1.8228335010602704e-06), 'frame.time_relative': np.float64(0.49085266079838535), 'frame.len': np.float64(0.013434579439252338), 'ip.src': np.float64(0.3488372093023256), 'ip.dst': np.float64(0.7441860465116279), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.033589219693454714), 'tcp.len': np.float64(0.005300353356890459), 'tcp.ack': np.float64(6.596976132957675e-05), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.012949640287769784), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.0), 'mqtt.conflags': np.float64(0.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.23076923076923078), 'mqtt.len': np.float64(0.010115606936416185), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.002389180425786083), 'mqtt.topic_len': np.float64(0.045454545454545456), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(1.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(2.700494075644845e-07), 'frame.time_relative': np.float64(0.28153615715328434), 'frame.len': np.float64(0.010514018691588786), 'ip.src': np.float64(0.7906976744186046), 'ip.dst': np.float64(0.9302325581395349), 'tcp.dstport': np.float64(0.5579354595206644), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(5.230079526523898e-06), 'tcp.len': np.float64(0.002355712603062426), 'tcp.ack': np.float64(0.004408881748327112), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.0057553956834532375), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.5384615384615385), 'mqtt.len': np.float64(0.002890173410404624), 'mqtt.msgtype': np.float64(0.7142857142857142), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0020905328725628228), 'mqtt.topic_len': np.float64(0.0), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.5), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(0.044865400961596434), 'frame.time_relative': np.float64(0.07518144670497028), 'frame.len': np.float64(0.014018691588785048), 'ip.src': np.float64(0.3023255813953488), 'ip.dst': np.float64(0.7441860465116279), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.03321640163599553), 'tcp.len': np.float64(0.005889281507656065), 'tcp.ack': np.float64(1.2259867149744352e-05), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.014388489208633094), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.23076923076923078), 'mqtt.len': np.float64(0.011560693641618497), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.002346516489611332), 'mqtt.topic_len': np.float64(0.045454545454545456), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(1.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(5.175946978319286e-07), 'frame.time_relative': np.float64(0.19407407715041053), 'frame.len': np.float64(0.01869158878504673), 'ip.src': np.float64(0.37209302325581395), 'ip.dst': np.float64(0.7441860465116279), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.033272166942539476), 'tcp.len': np.float64(0.010600706713780918), 'tcp.ack': np.float64(2.7438750287523073e-05), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.025899280575539568), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.23076923076923078), 'mqtt.len': np.float64(0.023121387283236993), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0026025001066598405), 'mqtt.topic_len': np.float64(0.18181818181818182), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(1.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(3.083064069694531e-06), 'frame.time_relative': np.float64(0.44062070609613957), 'frame.len': np.float64(0.015186915887850469), 'ip.src': np.float64(0.32558139534883723), 'ip.dst': np.float64(0.7441860465116279), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.033302331509490225), 'tcp.len': np.float64(0.007067137809187279), 'tcp.ack': np.float64(5.896412295829426e-05), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.017266187050359712), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.23076923076923078), 'mqtt.len': np.float64(0.014450867052023121), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0021758607449123258), 'mqtt.topic_len': np.float64(0.10606060606060606), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(1.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(0.0), 'frame.time_relative': np.float64(0.006693358377460245), 'frame.len': np.float64(0.0), 'ip.src': np.float64(0.9767441860465116), 'ip.dst': np.float64(1.0), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.2857142857142857), 'tcp.time_delta': np.float64(0.0), 'tcp.len': np.float64(0.0), 'tcp.ack': np.float64(0.0051193702398146775), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(0.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.0), 'tcp.pdu.size': np.float64(0.0), 'tcp.window_size_value': np.float64(0.06237888151369497), 'mqtt.conack.flags': np.float64(0.0), 'mqtt.conflags': np.float64(0.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.0), 'mqtt.len': np.float64(0.0), 'mqtt.msgtype': np.float64(0.0), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0020905328725628228), 'mqtt.topic_len': np.float64(0.0), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(4.050741113467268e-07), 'frame.time_relative': np.float64(0.6262296331134866), 'frame.len': np.float64(0.009345794392523366), 'ip.src': np.float64(0.7441860465116279), 'ip.dst': np.float64(0.20930232558139533), 'tcp.dstport': np.float64(0.5600113228911116), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(2.9981347604277124e-07), 'tcp.len': np.float64(0.001177856301531213), 'tcp.ack': np.float64(0.00024636494939010077), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.0028776978417266188), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.0), 'mqtt.conflags': np.float64(0.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.9230769230769231), 'mqtt.len': np.float64(0.0), 'mqtt.msgtype': np.float64(0.2857142857142857), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0020905328725628228), 'mqtt.topic_len': np.float64(0.0), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(1.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(2.2504117297040374e-08), 'frame.time_relative': np.float64(0.03597770718799772), 'frame.len': np.float64(0.0), 'ip.src': np.float64(0.9767441860465116), 'ip.dst': np.float64(1.0), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.14285714285714285), 'tcp.time_delta': np.float64(1.66563042245984e-08), 'tcp.len': np.float64(0.0), 'tcp.ack': np.float64(0.0), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(1.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(0.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(0.0), 'tcp.flags.reset': np.float64(1.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.0), 'tcp.pdu.size': np.float64(0.0), 'tcp.window_size_value': np.float64(0.0), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.0), 'mqtt.len': np.float64(0.0), 'mqtt.msgtype': np.float64(0.0), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0020905328725628228), 'mqtt.topic_len': np.float64(0.0), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(0.0), 'frame.time_relative': np.float64(0.00839179614773644), 'frame.len': np.float64(0.0461448598130841), 'ip.src': np.float64(0.9767441860465116), 'ip.dst': np.float64(1.0), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.0), 'tcp.len': np.float64(0.04652532391048292), 'tcp.ack': np.float64(0.009841170502059073), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.0), 'tcp.pdu.size': np.float64(0.2474820143884892), 'tcp.window_size_value': np.float64(0.06250095368886854), 'mqtt.conack.flags': np.float64(0.0), 'mqtt.conflags': np.float64(0.0), 'mqtt.dupflag': np.float64(1.0), 'mqtt.hdrflags': np.float64(0.46153846153846156), 'mqtt.len': np.float64(0.24421965317919073), 'mqtt.msgtype': np.float64(0.6428571428571428), 'mqtt.qos': np.float64(1.0), 'mqtt.topic': np.float64(0.502666496010922), 'mqtt.topic_len': np.float64(0.9848484848484849), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(4.500823459408075e-08), 'frame.time_relative': np.float64(0.0022030219056310605), 'frame.len': np.float64(0.0), 'ip.src': np.float64(0.9767441860465116), 'ip.dst': np.float64(1.0), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.2857142857142857), 'tcp.time_delta': np.float64(3.33126084491968e-08), 'tcp.len': np.float64(0.0), 'tcp.ack': np.float64(0.007627388776733807), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(0.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.0), 'tcp.pdu.size': np.float64(0.0), 'tcp.window_size_value': np.float64(0.062455176623178454), 'mqtt.conack.flags': np.float64(0.0), 'mqtt.conflags': np.float64(0.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.0), 'mqtt.len': np.float64(0.0), 'mqtt.msgtype': np.float64(0.0), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0020905328725628228), 'mqtt.topic_len': np.float64(0.0), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(0.0), 'frame.time_relative': np.float64(0.008251077251525648), 'frame.len': np.float64(0.0), 'ip.src': np.float64(0.9767441860465116), 'ip.dst': np.float64(1.0), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.2857142857142857), 'tcp.time_delta': np.float64(0.0), 'tcp.len': np.float64(0.0), 'tcp.ack': np.float64(0.015462027688618055), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(0.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.0), 'tcp.pdu.size': np.float64(0.0), 'tcp.window_size_value': np.float64(0.06242465857938506), 'mqtt.conack.flags': np.float64(0.0), 'mqtt.conflags': np.float64(0.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.0), 'mqtt.len': np.float64(0.0), 'mqtt.msgtype': np.float64(0.0), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0020905328725628228), 'mqtt.topic_len': np.float64(0.0), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(4.950905805348882e-07), 'frame.time_relative': np.float64(0.009492938928424998), 'frame.len': np.float64(0.0), 'ip.src': np.float64(0.9767441860465116), 'ip.dst': np.float64(1.0), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.2857142857142857), 'tcp.time_delta': np.float64(3.6643869294116484e-07), 'tcp.len': np.float64(0.0), 'tcp.ack': np.float64(0.01182143094834159), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(0.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.0), 'tcp.pdu.size': np.float64(0.0), 'tcp.window_size_value': np.float64(0.062455176623178454), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.0), 'mqtt.len': np.float64(0.0), 'mqtt.msgtype': np.float64(0.0), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0020905328725628228), 'mqtt.topic_len': np.float64(0.0), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(3.173080538882693e-06), 'frame.time_relative': np.float64(0.7868715850949918), 'frame.len': np.float64(0.015186915887850469), 'ip.src': np.float64(0.6744186046511628), 'ip.dst': np.float64(0.7441860465116279), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.03331340795179959), 'tcp.len': np.float64(0.007067137809187279), 'tcp.ack': np.float64(0.00010333316597641667), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.017266187050359712), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.0), 'mqtt.conflags': np.float64(0.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.23076923076923078), 'mqtt.len': np.float64(0.014450867052023121), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0021758607449123258), 'mqtt.topic_len': np.float64(0.10606060606060606), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(1.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(1.80032938376323e-07), 'frame.time_relative': np.float64(0.16763591155597454), 'frame.len': np.float64(0.015186915887850469), 'ip.src': np.float64(0.9302325581395349), 'ip.dst': np.float64(0.7906976744186046), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.049977507326775104), 'tcp.len': np.float64(0.007067137809187279), 'tcp.ack': np.float64(0.0008856294507696277), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.017266187050359712), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.38461538461538464), 'mqtt.len': np.float64(0.014450867052023121), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(1.0), 'mqtt.topic': np.float64(0.002645164042834592), 'mqtt.topic_len': np.float64(0.07575757575757576), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.5), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(4.118253465358389e-06), 'frame.time_relative': np.float64(0.8298299264164047), 'frame.len': np.float64(0.01869158878504673), 'ip.src': np.float64(0.37209302325581395), 'ip.dst': np.float64(0.7441860465116279), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.03333131347884103), 'tcp.len': np.float64(0.010600706713780918), 'tcp.ack': np.float64(0.00010917119795248542), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.025899280575539568), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.0), 'mqtt.conflags': np.float64(0.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.23076923076923078), 'mqtt.len': np.float64(0.023121387283236993), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0026025001066598405), 'mqtt.topic_len': np.float64(0.18181818181818182), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(1.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(6.301152843171305e-07), 'frame.time_relative': np.float64(0.1435204908175775), 'frame.len': np.float64(0.010514018691588786), 'ip.src': np.float64(0.7674418604651163), 'ip.dst': np.float64(0.16279069767441862), 'tcp.dstport': np.float64(0.6161854437944266), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(4.6637651828875527e-07), 'tcp.len': np.float64(0.002355712603062426), 'tcp.ack': np.float64(0.0022604859811338157), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.0057553956834532375), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.5384615384615385), 'mqtt.len': np.float64(0.002890173410404624), 'mqtt.msgtype': np.float64(0.7142857142857142), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0020905328725628228), 'mqtt.topic_len': np.float64(0.0), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.5), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(1.5302799761987455e-06), 'frame.time_relative': np.float64(0.14040867443710972), 'frame.len': np.float64(0.010514018691588786), 'ip.src': np.float64(0.7906976744186046), 'ip.dst': np.float64(0.9302325581395349), 'tcp.dstport': np.float64(0.6771088884695227), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(1.6822867266844387e-06), 'tcp.len': np.float64(0.002355712603062426), 'tcp.ack': np.float64(0.002211446512534838), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.0057553956834532375), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.5384615384615385), 'mqtt.len': np.float64(0.002890173410404624), 'mqtt.msgtype': np.float64(0.7142857142857142), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0020905328725628228), 'mqtt.topic_len': np.float64(0.0), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.5), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(1.9443557344642884e-05), 'frame.time_relative': np.float64(0.0012684441885056222), 'frame.len': np.float64(0.004672897196261683), 'ip.src': np.float64(1.0), 'ip.dst': np.float64(0.9767441860465116), 'tcp.dstport': np.float64(0.828363842234384), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(1.4391046850053019e-05), 'tcp.len': np.float64(0.004711425206124852), 'tcp.ack': np.float64(0.11858969493947712), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.0), 'tcp.pdu.size': np.float64(0.0057553956834532375), 'tcp.window_size_value': np.float64(0.007827878233005264), 'mqtt.conack.flags': np.float64(0.0), 'mqtt.conflags': np.float64(0.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.5384615384615385), 'mqtt.len': np.float64(0.002890173410404624), 'mqtt.msgtype': np.float64(0.7857142857142857), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0020905328725628228), 'mqtt.topic_len': np.float64(0.0), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(1.0), 'class': np.float64(0.0), 'label': 0}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(1.912849970248432e-06), 'frame.time_relative': np.float64(0.2933348443637766), 'frame.len': np.float64(0.010514018691588786), 'ip.src': np.float64(0.7906976744186046), 'ip.dst': np.float64(0.9534883720930233), 'tcp.dstport': np.float64(0.675756432031201), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(1.4157858590908643e-06), 'tcp.len': np.float64(0.002355712603062426), 'tcp.ack': np.float64(0.0042144752835240225), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.0057553956834532375), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.5384615384615385), 'mqtt.len': np.float64(0.002890173410404624), 'mqtt.msgtype': np.float64(0.7142857142857142), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0020905328725628228), 'mqtt.topic_len': np.float64(0.0), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.5), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# ...
# Publicado no Kafka: {'frame.time_delta': np.float64(6.076111670200901e-07), 'frame.time_relative': np.float64(0.4733036244322951), 'frame.len': np.float64(0.015186915887850469), 'ip.src': np.float64(0.6744186046511628), 'ip.dst': np.float64(0.7441860465116279), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.03332954791059322), 'tcp.len': np.float64(0.007067137809187279), 'tcp.ack': np.float64(6.363454853914925e-05), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.017266187050359712), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.0), 'mqtt.conflags': np.float64(0.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.23076923076923078), 'mqtt.len': np.float64(0.014450867052023121), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0021758607449123258), 'mqtt.topic_len': np.float64(0.10606060606060606), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(1.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(2.0028664394365932e-06), 'frame.time_relative': np.float64(0.4297418911969223), 'frame.len': np.float64(0.01869158878504673), 'ip.src': np.float64(0.7209302325581395), 'ip.dst': np.float64(0.7441860465116279), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.03333667680880135), 'tcp.len': np.float64(0.010600706713780918), 'tcp.ack': np.float64(5.779651656308051e-05), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.025899280575539568), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.0), 'mqtt.conflags': np.float64(0.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.23076923076923078), 'mqtt.len': np.float64(0.023121387283236993), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0026025001066598405), 'mqtt.topic_len': np.float64(0.18181818181818182), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(1.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(5.851070497230497e-07), 'frame.time_relative': np.float64(5.3702911496648906e-05), 'frame.len': np.float64(0.008761682242990655), 'ip.src': np.float64(0.0), 'ip.dst': np.float64(0.023255813953488372), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(7.845119289785847e-06), 'tcp.len': np.float64(0.0017667844522968198), 'tcp.ack': np.float64(5.838031976068739e-07), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.0460431654676259), 'tcp.window_size_value': np.float64(0.0034943160143434807), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(1.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.07692307692307693), 'mqtt.len': np.float64(0.04335260115606936), 'mqtt.msgtype': np.float64(0.14285714285714285), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0021331968087375743), 'mqtt.topic_len': np.float64(0.0), 'mqtt.ver': np.float64(1.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(1.1252058648520189e-07), 'frame.time_relative': np.float64(4.62529469947647e-06), 'frame.len': np.float64(0.008177570093457945), 'ip.src': np.float64(0.0), 'ip.dst': np.float64(0.023255813953488372), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(3.397886061818074e-06), 'tcp.len': np.float64(0.001177856301531213), 'tcp.ack': np.float64(5.838031976068739e-07), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.0460431654676259), 'tcp.window_size_value': np.float64(0.0034943160143434807), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(1.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.07692307692307693), 'mqtt.len': np.float64(0.04335260115606936), 'mqtt.msgtype': np.float64(0.14285714285714285), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0021331968087375743), 'mqtt.topic_len': np.float64(0.0), 'mqtt.ver': np.float64(1.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(1.80032938376323e-07), 'frame.time_relative': np.float64(0.16336721031797902), 'frame.len': np.float64(0.009345794392523366), 'ip.src': np.float64(0.7441860465116279), 'ip.dst': np.float64(0.27906976744186046), 'tcp.dstport': np.float64(0.5192174624142921), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(4.613796270213758e-06), 'tcp.len': np.float64(0.001177856301531213), 'tcp.ack': np.float64(8.523526685060359e-05), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.0028776978417266188), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.9230769230769231), 'mqtt.len': np.float64(0.0), 'mqtt.msgtype': np.float64(0.2857142857142857), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0020905328725628228), 'mqtt.topic_len': np.float64(0.0), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(1.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(9.451729264756957e-07), 'frame.time_relative': np.float64(0.28979141846775336), 'frame.len': np.float64(0.01752336448598131), 'ip.src': np.float64(0.46511627906976744), 'ip.dst': np.float64(0.7674418604651163), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.0833109028436442), 'tcp.len': np.float64(0.009422850412249705), 'tcp.ack': np.float64(3.911481423966055e-05), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.02302158273381295), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.23076923076923078), 'mqtt.len': np.float64(0.02023121387283237), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0022185246810870773), 'mqtt.topic_len': np.float64(0.13636363636363635), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.5), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(2.9255352486152487e-07), 'frame.time_relative': np.float64(0.245049625194936), 'frame.len': np.float64(0.009345794392523366), 'ip.src': np.float64(0.7441860465116279), 'ip.dst': np.float64(0.6046511627906976), 'tcp.dstport': np.float64(0.5314839277851168), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(2.1653195491977922e-07), 'tcp.len': np.float64(0.001177856301531213), 'tcp.ack': np.float64(0.00011325782033573354), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.0028776978417266188), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.9230769230769231), 'mqtt.len': np.float64(0.0), 'mqtt.msgtype': np.float64(0.2857142857142857), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0020905328725628228), 'mqtt.topic_len': np.float64(0.0), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(1.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(2.768006427535966e-06), 'frame.time_relative': np.float64(0.1532228367945788), 'frame.len': np.float64(0.01869158878504673), 'ip.src': np.float64(0.37209302325581395), 'ip.dst': np.float64(0.7441860465116279), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.03329018906371049), 'tcp.len': np.float64(0.010600706713780918), 'tcp.ack': np.float64(2.1600718311454334e-05), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.025899280575539568), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.23076923076923078), 'mqtt.len': np.float64(0.023121387283236993), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0026025001066598405), 'mqtt.topic_len': np.float64(0.18181818181818182), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(1.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(2.768006427535966e-06), 'frame.time_relative': np.float64(0.20525696501601162), 'frame.len': np.float64(0.01869158878504673), 'ip.src': np.float64(0.37209302325581395), 'ip.dst': np.float64(0.7441860465116279), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.03331982062892606), 'tcp.len': np.float64(0.010600706713780918), 'tcp.ack': np.float64(2.860635668273682e-05), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.025899280575539568), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.5), 'mqtt.conflags': np.float64(0.5), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.23076923076923078), 'mqtt.len': np.float64(0.023121387283236993), 'mqtt.msgtype': np.float64(0.5714285714285714), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0026025001066598405), 'mqtt.topic_len': np.float64(0.18181818181818182), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(1.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(6.526194016141709e-07), 'frame.time_relative': np.float64(0.39026099944738907), 'frame.len': np.float64(0.009345794392523366), 'ip.src': np.float64(0.7441860465116279), 'ip.dst': np.float64(0.32558139534883723), 'tcp.dstport': np.float64(0.6379505567088131), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(4.830328225133537e-07), 'tcp.len': np.float64(0.001177856301531213), 'tcp.ack': np.float64(0.00910966509545766), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.5), 'tcp.pdu.size': np.float64(0.0028776978417266188), 'tcp.window_size_value': np.float64(0.007812619211108568), 'mqtt.conack.flags': np.float64(0.0), 'mqtt.conflags': np.float64(0.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.9230769230769231), 'mqtt.len': np.float64(0.0), 'mqtt.msgtype': np.float64(0.2857142857142857), 'mqtt.qos': np.float64(0.0), 'mqtt.topic': np.float64(0.0020905328725628228), 'mqtt.topic_len': np.float64(0.0), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(1.0), 'label': 1}
# Mensagem enviada com sucesso para kf-topic [0]
# Publicado no Kafka: {'frame.time_delta': np.float64(0.0), 'frame.time_relative': np.float64(0.0012938942002291363), 'frame.len': np.float64(0.05198598130841121), 'ip.src': np.float64(0.9767441860465116), 'ip.dst': np.float64(1.0), 'tcp.dstport': np.float64(0.0), 'tcp.flags': np.float64(0.8571428571428571), 'tcp.time_delta': np.float64(0.0), 'tcp.len': np.float64(0.052414605418138985), 'tcp.ack': np.float64(0.0037836285236901497), 'tcp.connection.fin': np.float64(0.0), 'tcp.connection.rst': np.float64(0.0), 'tcp.connection.sack': np.float64(0.0), 'tcp.connection.syn': np.float64(0.0), 'tcp.flags.ack': np.float64(1.0), 'tcp.flags.fin': np.float64(0.0), 'tcp.flags.push': np.float64(1.0), 'tcp.flags.reset': np.float64(0.0), 'tcp.flags.syn': np.float64(0.0), 'tcp.hdr_len': np.float64(0.0), 'tcp.pdu.size': np.float64(0.25323741007194245), 'tcp.window_size_value': np.float64(0.06250095368886854), 'mqtt.conack.flags': np.float64(0.0), 'mqtt.conflags': np.float64(0.0), 'mqtt.dupflag': np.float64(0.0), 'mqtt.hdrflags': np.float64(0.38461538461538464), 'mqtt.len': np.float64(0.25), 'mqtt.msgtype': np.float64(0.6428571428571428), 'mqtt.qos': np.float64(1.0), 'mqtt.topic': np.float64(0.9309270873330774), 'mqtt.topic_len': np.float64(0.9848484848484849), 'mqtt.ver': np.float64(0.0), 'ip.ttl': np.float64(0.0), 'class': np.float64(0.0), 'label': 1}

# %%
# !pip uninstall kafka kafka-python -y
# !pip install kafka-python
# !pip install confluent-kafka
# !pip uninstall kafka kafka-python -y
# Out:
# Found existing installation: kafka 1.3.5
# Uninstalling kafka-1.3.5:
#   Successfully uninstalled kafka-1.3.5
# WARNING: Skipping kafka-python as it is not installed.
# Collecting kafka-python
#   Using cached kafka_python-2.0.2-py2.py3-none-any.whl.metadata (7.8 kB)
# Using cached kafka_python-2.0.2-py2.py3-none-any.whl (246 kB)
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.0.2
# Requirement already satisfied: confluent-kafka in /opt/conda/lib/python3.11/site-packages (2.6.1)
# WARNING: Skipping kafka as it is not installed.
# Found existing installation: kafka-python 2.0.2
# Uninstalling kafka-python-2.0.2:
#   Successfully uninstalled kafka-python-2.0.2
